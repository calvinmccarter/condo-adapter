# %%
from collections import defaultdict
from itertools import product

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import time
import warnings

import condo

# %%
plt.rcParams["xtick.major.size"] = 2
plt.rcParams["ytick.major.size"] = 2
plt.rcParams['axes.linewidth'] = 0.5
plt.rc('font', size=7) #controls default text size
plt.rc('axes', titlesize=7) #fontsize of the title
plt.rc('axes', labelsize=7) #fontsize of the x and y labels
plt.rc('xtick', labelsize=7) #fontsize of the x tick labels
plt.rc('ytick', labelsize=7) #fontsize of the y tick labels
plt.rc('legend', fontsize=7) #fontsize of the legend
plt.ioff();

# %%
def split_sum(arr, num_cols, rng):
    N, M = arr.shape
    assert np.min(arr) > 0
    assert M == 1
    newarr = np.zeros((N, num_cols))
    for i in range(N):
        total = arr[i, 0]
        dividers = sorted(rng.uniform(0, total, size=(num_cols-1,)))
        newarr[i, :] = np.array(
            [a - b for a, b in zip(dividers + [total], [0] + dividers)]
        ).reshape(1, -1)
    return newarr

# %%
N_T = 200
N_S = 100
mmd_size = 20

# How batch effect affects S
batch_m = 2
batch_b = 5

# The true batch correction from Sbatch to S
true_m = 1. / batch_m
true_b = -1 * batch_b / batch_m

noise_settings = ["NoiseFree"]
targetshift_settings = ["TargetShift"]
featureshift_settings = ["FeatureShift"]
multivar_settings = ["1", "2", "4", "8", "16", "32"]

prob_settings = ["Homoscedastic Linear", "Heteroscedastic Linear", "Nonlinear"]
num_probs = len(prob_settings)

# method -> (num_Ns, num_random) array
rMSEs = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
rMSEs_test = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
num_random = 10
for rix in range(num_random):
    rng = np.random.RandomState(rix)
    for setting_combo in product(noise_settings, targetshift_settings, featureshift_settings, multivar_settings):
        (noise_setting, targetshift_setting, featureshift_setting, multivar_setting) = setting_combo
        setting_str = "-".join(setting_combo)
        assert noise_setting in ("Noisy", "NoiseFree")
        assert targetshift_setting in ("NoTargetShift", "TargetShift")
        assert featureshift_setting in ("NoFeatureShift", "FeatureShift")
        num_c = int(multivar_setting)

        fig, axes = plt.subplots(
            nrows=7, ncols=num_probs, sharex="all", sharey="all", squeeze=False,
            gridspec_kw={"hspace": 0.03, "wspace": 0.03},
            figsize=(6, 10), dpi=150)
        msize = 1
        basic_leg = ['target', 'source: batch-effected', 'source: true (unobserved)']
        figname = f"figure-continuous1d-split-{setting_str}-{rix}.pdf"
        fsizemse = 7

        for pix, prob_setting in enumerate(prob_settings):
            print(f"rix:{rix} {setting_str} {prob_setting}")
            # Distribution of confounders
            X_T = np.sort(rng.uniform(0, 8, size=(N_T,)))
            if targetshift_setting == "TargetShift":
                X_S = np.sort(rng.uniform(4, 8, size=(N_S,)))
                X_S_test = np.sort(rng.uniform(0, 8, size=(N_S,)))
            elif targetshift_setting == "NoTargetShift":
                X_S = np.sort(rng.uniform(0, 8, size=(N_S,)))
                X_S_test = np.sort(rng.uniform(0, 8, size=(N_S,)))
            
            if prob_setting == "Homoscedastic Linear":
                # How confounder X affects the distribution of T and S
                theta_m = 4
                theta_b = 1
                phi_m = 0
                phi_b = 2
                mu_T = theta_m * X_T + theta_b
                mu_S = theta_m * X_S + theta_b
                mu_S_test = theta_m * X_S_test + theta_b
                sigma_T = phi_m * X_T + phi_b
                sigma_S = phi_m * X_S + phi_b
                sigma_S_test = phi_m * X_S_test + phi_b
                T = rng.normal(mu_T, sigma_T)
                Strue = rng.normal(mu_S, sigma_S)
                Strue_test = rng.normal(mu_S_test, sigma_S_test)
            elif prob_setting == "Heteroscedastic Linear":
                # How confounder X affects the distribution of T and S
                theta_m = 4
                theta_b = 1
                phi_m = 1
                phi_b = 1
                mu_T = theta_m * X_T + theta_b
                mu_S = theta_m * X_S + theta_b
                mu_S_test = theta_m * X_S_test + theta_b
                sigma_T = phi_m * X_T + phi_b
                sigma_S = phi_m * X_S + phi_b
                sigma_S_test = phi_m * X_S_test + phi_b
                T = rng.normal(mu_T, sigma_T)
                Strue = rng.normal(mu_S, sigma_S)
                Strue_test = rng.normal(mu_S_test, sigma_S_test)
            elif prob_setting == "Nonlinear":
                # How confounder X affects the distribution of T and S
                theta_m = 4
                theta_b = 1
                phi_m = 1
                phi_b = 1
                mu_T = theta_m * (np.maximum(X_T-5, 0) ** 2) + theta_b
                mu_S = theta_m * (np.maximum(X_S-5, 0) ** 2) + theta_b
                mu_S_test = theta_m * (np.maximum(X_S_test-5, 0) ** 2) + theta_b
                sigma_T = phi_m * (np.maximum(X_T-5, 0) ** 2) + phi_b
                sigma_S = phi_m * (np.maximum(X_S-5, 0) ** 2) + phi_b
                sigma_S_test = phi_m * (np.maximum(X_S_test-5, 0) ** 2) + phi_b
                T = rng.normal(mu_T, sigma_T)
                Strue = rng.normal(mu_S, sigma_S)
                Strue_test = rng.normal(mu_S_test, sigma_S_test)
            if featureshift_setting == "FeatureShift":
                Sbatch = batch_m * Strue + batch_b
                Sbatch_test = batch_m * Strue_test + batch_b
                oracle_m = true_m
                oracle_b = true_b
            elif featureshift_setting == "NoFeatureShift":
                oracle_m = 1.0
                oracle_b = 0.0
                Sbatch = Strue.copy()
                Sbatch_test = Strue_test.copy()

            if noise_setting == "NoiseFree":
                pass
            elif noise_setting == "Noisy":
                Sbatch = Sbatch + rng.normal(0, 1, size=(N_S,))
                Sbatch_test = Sbatch_test + rng.normal(0, 1, size=(N_S,))

            T_ = T.reshape(-1, 1) # (N_T, 1)
            Strue_ = Strue.reshape(-1, 1) # (N_S, 1)
            Sbatch_ = Sbatch.reshape(-1, 1)
            X_T_ = X_T.reshape(-1, 1) # (N_T, 1)
            X_S_ = X_S.reshape(-1, 1)
            Strue_test_ = Strue_test.reshape(-1, 1) # (N_S, 1)
            Sbatch_test_ = Sbatch_test.reshape(-1, 1)
            X_S_test_ = X_S_test.reshape(-1, 1)
            
            # Before correction
            method = "batch-effected"
            rMSE = np.sqrt(np.mean((Sbatch - Strue) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sbatch_test - Strue_test) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[0, pix].tick_params(axis="both", which="both", direction="in")    
            axes[0, pix].scatter(X_T, T, s=msize)
            axes[0, pix].scatter(X_S, Sbatch, s=msize)
            axes[0, pix].scatter(X_S, Strue, s=msize)
            axes[0, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[0, pix].transAxes);
            if pix == num_probs - 1:
                axes[0, pix].legend(
                    basic_leg,
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            # Oracle - not displayed
            method = "Oracle"
            Soracle = oracle_m * Sbatch + oracle_b
            Soracle_test = oracle_m * Sbatch_test + oracle_b
            rMSE = np.sqrt(np.mean((Soracle - Strue) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Soracle_test - Strue_test) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")

            # OTDA
            method = "Gaussian OT"
            lter = condo.AdapterGaussianOT()
            lter.fit(Xs=Sbatch_, Xt=T_)
            Sotda_ = lter.transform(Xs=Sbatch_)
            Sotda_test_ = lter.transform(Xs=Sbatch_test_)
            rMSE = np.sqrt(np.mean((Sotda_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sotda_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[1, pix].tick_params(axis="both", which="both", direction="in")    
            axes[1, pix].scatter(X_T, T, s=msize)
            axes[1, pix].scatter(X_S, Sbatch, s=msize)
            axes[1, pix].scatter(X_S, Strue, s=msize)
            axes[1, pix].scatter(X_S, Sotda_, s=msize)
            axes[1, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[1, pix].transAxes);
            if pix == num_probs - 1:
                axes[1, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            # MMD
            method = "MMD"
            cder = condo.AdapterMMD(
                transform_type="location-scale",
                n_epochs=100,
                learning_rate=1e-2,
                mmd_size=mmd_size,
            )
            cder.fit(Sbatch_, T_)
            Smmd_ = cder.transform(Sbatch_)
            Smmd_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Smmd_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Smmd_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting]);
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[2, pix].tick_params(axis="both", which="both", direction="in")    
            axes[2, pix].scatter(X_T, T, s=msize)
            axes[2, pix].scatter(X_S, Sbatch, s=msize)
            axes[2, pix].scatter(X_S, Strue, s=msize)
            axes[2, pix].scatter(X_S, Smmd_, s=msize)
            axes[2, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[2, pix].transAxes);
            if pix == num_probs - 1:
                axes[2, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            method = "ConDo Gaussian KLD"
            cder = condo.ConDoAdapterKLD(
                transform_type="location-scale",
                verbose=0,
            )
            cder.fit(Sbatch_, T_, split_sum(X_S_, num_c, rng), split_sum(X_T_, num_c, rng))
            Sreverse_ = cder.transform(Sbatch_)
            Sreverse_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Sreverse_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sreverse_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[3, pix].tick_params(axis="both", which="both", direction="in")    
            axes[3, pix].scatter(X_T, T, s=msize)
            axes[3, pix].scatter(X_S, Sbatch, s=msize)
            axes[3, pix].scatter(X_S, Strue, s=msize)
            axes[3, pix].scatter(X_S, Sreverse_, s=msize)
            axes[3, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[3, pix].transAxes);
            if pix == num_probs - 1:
                axes[3, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);            

            # Condo using MMD
            method = "ConDo MMD"
            cder = condo.ConDoAdapterMMD(
                transform_type="location-scale",
                n_epochs=100,
                learning_rate=1e-2,
                mmd_size=mmd_size,
            )
            cder.fit(Sbatch_, T_, split_sum(X_S_, num_c, rng), split_sum(X_T_, num_c, rng))
            Smmd_ = cder.transform(Sbatch_)
            Smmd_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Smmd_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Smmd_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting]);
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[4, pix].tick_params(axis="both", which="both", direction="in")    
            axes[4, pix].scatter(X_T, T, s=msize)
            axes[4, pix].scatter(X_S, Sbatch, s=msize)
            axes[4, pix].scatter(X_S, Strue, s=msize)
            axes[4, pix].scatter(X_S, Smmd_, s=msize)
            axes[4, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[4, pix].transAxes);
            if pix == num_probs - 1:
                axes[4, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);
        plt.close()
# Out:
# rix:0 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.110  (22.992)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.049  (17.721)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 4.996  (4.865)
#     ConDo Gaussian KLD rMSE: 0.459  (1.218)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.359  (0.939)
# rix:0 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.425  (26.066)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.538  (11.201)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.732  (7.072)
#     ConDo Gaussian KLD rMSE: 0.873  (1.374)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.278  (2.222)
# rix:0 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 17.877  (15.738)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.535  (4.148)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.486  (7.458)
#     ConDo Gaussian KLD rMSE: 1.870  (2.034)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.422  (1.250)
# rix:0 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 29.973  (24.171)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.225  (17.023)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.682  (5.678)
#     ConDo Gaussian KLD rMSE: 0.553  (1.038)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.372  (0.760)
# rix:0 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 30.783  (25.002)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.373  (12.612)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.634  (7.699)
#     ConDo Gaussian KLD rMSE: 1.881  (1.634)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.850  (1.003)
# rix:0 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 17.613  (13.771)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.495  (2.966)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.196  (5.520)
#     ConDo Gaussian KLD rMSE: 2.172  (2.170)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.844  (2.206)
# rix:0 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.384  (23.183)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.717  (15.220)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 3.763  (3.924)
#     ConDo Gaussian KLD rMSE: 0.907  (1.167)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.269  (1.083)
# rix:0 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 31.240  (24.153)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.483  (11.594)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.447  (6.838)
#     ConDo Gaussian KLD rMSE: 0.862  (1.361)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.184  (1.219)
# rix:0 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 20.312  (15.844)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.283  (5.854)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 10.986  (8.460)
#     ConDo Gaussian KLD rMSE: 3.959  (3.319)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.295  (4.122)
# rix:0 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.635  (23.342)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 10.500  (20.941)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.404  (6.565)
#     ConDo Gaussian KLD rMSE: 2.055  (1.630)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.785  (2.001)
# rix:0 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 32.797  (25.578)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.134  (9.976)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.160  (7.097)
#     ConDo Gaussian KLD rMSE: 2.834  (2.088)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.650  (1.038)
# rix:0 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 15.778  (13.691)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 2.233  (2.155)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 4.562  (3.944)
#     ConDo Gaussian KLD rMSE: 3.290  (3.104)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.686  (4.147)
# rix:0 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 29.712  (23.109)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.649  (15.412)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 3.571  (3.884)
#     ConDo Gaussian KLD rMSE: 1.166  (1.248)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.415  (0.916)
# rix:0 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 29.902  (27.085)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.095  (9.150)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.897  (5.690)
#     ConDo Gaussian KLD rMSE: 5.530  (5.123)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.492  (4.147)
# rix:0 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 16.544  (12.410)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 2.289  (2.495)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.153  (4.478)
#     ConDo Gaussian KLD rMSE: 3.568  (2.875)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.534  (1.194)
# rix:0 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.456  (23.572)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.106  (16.336)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.268  (5.929)
#     ConDo Gaussian KLD rMSE: 5.139  (3.684)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.482  (1.019)
# rix:0 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.268  (22.390)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.477  (11.380)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.124  (7.673)
#     ConDo Gaussian KLD rMSE: 8.901  (5.802)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.744  (2.495)
# rix:0 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 16.177  (11.828)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.644  (2.994)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.477  (5.687)
#     ConDo Gaussian KLD rMSE: 5.549  (3.696)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.111  (2.065)
# rix:1 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.772  (23.538)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 10.009  (19.895)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.000  (4.207)
#     ConDo Gaussian KLD rMSE: 0.497  (1.140)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.413  (0.883)
# rix:1 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.769  (25.719)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.086  (12.222)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.240  (7.714)
#     ConDo Gaussian KLD rMSE: 0.776  (1.317)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.477  (1.594)
# rix:1 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 16.913  (12.670)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.223  (3.111)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.836  (5.064)
#     ConDo Gaussian KLD rMSE: 1.999  (2.165)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.786  (1.181)
# rix:1 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.227  (24.198)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.651  (18.025)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.073  (5.937)
#     ConDo Gaussian KLD rMSE: 0.602  (1.054)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.801  (0.908)
# rix:1 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 30.649  (25.291)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.556  (10.634)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.726  (6.978)
#     ConDo Gaussian KLD rMSE: 2.247  (1.938)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.066  (1.130)
# rix:1 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.944  (13.673)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.540  (3.603)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.362  (5.781)
#     ConDo Gaussian KLD rMSE: 3.072  (2.418)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.766  (1.939)
# rix:1 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.344  (23.113)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.370  (16.109)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.184  (5.013)
#     ConDo Gaussian KLD rMSE: 1.311  (1.247)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.988  (0.942)
# rix:1 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 30.975  (24.437)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.950  (11.036)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.248  (6.638)
#     ConDo Gaussian KLD rMSE: 1.354  (1.455)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.148  (1.298)
# rix:1 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.872  (15.159)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.083  (5.230)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 10.107  (7.578)
#     ConDo Gaussian KLD rMSE: 3.529  (2.911)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.270  (3.228)
# rix:1 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.630  (23.424)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.747  (19.354)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.278  (5.746)
#     ConDo Gaussian KLD rMSE: 1.958  (1.600)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.567  (1.483)
# rix:1 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 32.325  (24.783)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.602  (9.981)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.542  (6.659)
#     ConDo Gaussian KLD rMSE: 2.486  (1.836)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.586  (2.076)
# rix:1 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 17.156  (14.444)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 2.915  (2.632)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.270  (5.177)
#     ConDo Gaussian KLD rMSE: 4.579  (3.940)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.877  (2.546)
# rix:1 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 29.982  (22.755)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.377  (17.611)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 4.565  (4.484)
#     ConDo Gaussian KLD rMSE: 2.344  (1.821)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.368  (1.257)
# rix:1 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 29.538  (25.794)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.447  (10.165)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.538  (6.275)
#     ConDo Gaussian KLD rMSE: 3.141  (3.206)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 6.959  (6.102)
# rix:1 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 19.039  (13.509)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.174  (4.245)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.990  (6.626)
#     ConDo Gaussian KLD rMSE: 7.446  (4.930)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.796  (1.852)
# rix:1 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.382  (24.297)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.224  (15.885)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.256  (5.960)
#     ConDo Gaussian KLD rMSE: 4.305  (3.200)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.225  (3.676)
# rix:1 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.925  (22.488)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.815  (12.082)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.431  (7.854)
#     ConDo Gaussian KLD rMSE: 7.391  (4.703)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.749  (2.707)
# rix:1 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.076  (14.077)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.405  (3.714)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.587  (6.367)
#     ConDo Gaussian KLD rMSE: 6.000  (4.521)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.842  (1.326)
# rix:2 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.748  (23.089)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.964  (19.047)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.027  (5.105)
#     ConDo Gaussian KLD rMSE: 0.496  (1.166)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.500  (0.894)
# rix:2 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.805  (25.496)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.254  (11.668)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.191  (7.745)
#     ConDo Gaussian KLD rMSE: 1.557  (1.684)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.832  (1.717)
# rix:2 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.101  (13.251)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.036  (4.098)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.385  (6.530)
#     ConDo Gaussian KLD rMSE: 2.384  (2.198)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.678  (1.747)
# rix:2 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.506  (23.905)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.867  (17.809)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.887  (6.463)
#     ConDo Gaussian KLD rMSE: 0.780  (1.042)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.977  (0.917)
# rix:2 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 30.851  (24.132)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.573  (10.841)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.775  (6.907)
#     ConDo Gaussian KLD rMSE: 2.049  (1.743)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.032  (1.573)
# rix:2 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 19.387  (13.494)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.353  (4.093)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.287  (6.085)
#     ConDo Gaussian KLD rMSE: 3.089  (2.305)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.410  (2.203)
# rix:2 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.130  (23.468)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.539  (16.006)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.446  (5.248)
#     ConDo Gaussian KLD rMSE: 1.327  (1.305)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.224  (1.116)
# rix:2 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 31.352  (24.228)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.275  (11.189)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.205  (6.512)
#     ConDo Gaussian KLD rMSE: 1.157  (1.379)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.120  (1.355)
# rix:2 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.028  (14.570)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.195  (4.484)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.971  (6.723)
#     ConDo Gaussian KLD rMSE: 3.048  (2.602)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.296  (2.509)
# rix:2 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.675  (23.459)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.684  (18.814)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.933  (5.544)
#     ConDo Gaussian KLD rMSE: 1.789  (1.496)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.168  (1.307)
# rix:2 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.844  (24.906)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.802  (10.480)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.878  (7.049)
#     ConDo Gaussian KLD rMSE: 2.257  (1.757)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.127  (1.770)
# rix:2 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.328  (14.236)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.016  (3.298)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.370  (5.459)
#     ConDo Gaussian KLD rMSE: 5.526  (4.139)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.977  (3.578)
# rix:2 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 29.723  (22.933)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.183  (17.243)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 3.751  (3.946)
#     ConDo Gaussian KLD rMSE: 1.750  (1.575)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.578  (1.503)
# rix:2 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 29.796  (25.563)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.444  (9.736)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.901  (6.515)
#     ConDo Gaussian KLD rMSE: 2.429  (2.603)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.165  (4.622)
# rix:2 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 19.659  (13.150)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.793  (4.376)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 10.939  (6.703)
#     ConDo Gaussian KLD rMSE: 7.658  (4.690)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.280  (2.494)
# rix:2 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.302  (24.087)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.225  (16.374)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.008  (5.757)
#     ConDo Gaussian KLD rMSE: 4.747  (3.501)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.661  (3.064)
# rix:2 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.397  (23.140)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.383  (12.058)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.988  (7.690)
#     ConDo Gaussian KLD rMSE: 7.188  (4.875)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.364  (2.476)
# rix:2 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.190  (15.494)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.789  (4.287)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.217  (7.861)
#     ConDo Gaussian KLD rMSE: 6.150  (5.327)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.942  (3.720)
# rix:3 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.617  (23.198)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.692  (18.256)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.819  (5.120)
#     ConDo Gaussian KLD rMSE: 0.528  (1.145)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.477  (0.891)
# rix:3 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.646  (25.257)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.900  (10.859)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.808  (7.459)
#     ConDo Gaussian KLD rMSE: 1.419  (1.579)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.614  (1.549)
# rix:3 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 17.832  (13.148)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.691  (3.788)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.575  (6.015)
#     ConDo Gaussian KLD rMSE: 2.270  (2.146)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.430  (1.622)
# rix:3 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.692  (23.959)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 10.032  (17.587)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.975  (6.529)
#     ConDo Gaussian KLD rMSE: 0.917  (1.073)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.111  (0.970)
# rix:3 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.049  (24.142)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.872  (10.836)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.464  (7.419)
#     ConDo Gaussian KLD rMSE: 2.139  (1.751)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.164  (1.632)
# rix:3 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 19.061  (13.404)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.084  (3.886)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.729  (5.774)
#     ConDo Gaussian KLD rMSE: 2.972  (2.259)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.202  (2.092)
# rix:3 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.163  (23.790)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.717  (16.038)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.524  (5.322)
#     ConDo Gaussian KLD rMSE: 1.494  (1.395)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.381  (1.209)
# rix:3 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 31.348  (24.899)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.332  (10.786)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.358  (6.674)
#     ConDo Gaussian KLD rMSE: 1.165  (1.365)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.352  (1.467)
# rix:3 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.189  (15.307)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.344  (4.668)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.489  (7.512)
#     ConDo Gaussian KLD rMSE: 3.192  (2.822)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.309  (3.543)
# rix:3 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.568  (23.573)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.541  (19.403)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.636  (5.051)
#     ConDo Gaussian KLD rMSE: 1.674  (1.456)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.255  (1.297)
# rix:3 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.568  (24.607)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.760  (10.564)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.937  (7.081)
#     ConDo Gaussian KLD rMSE: 2.016  (1.658)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.019  (1.778)
# rix:3 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.505  (14.228)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.234  (3.517)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.376  (6.134)
#     ConDo Gaussian KLD rMSE: 4.756  (3.641)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.147  (3.697)
# rix:3 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 29.882  (23.371)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.326  (17.118)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 4.150  (4.277)
#     ConDo Gaussian KLD rMSE: 1.752  (1.551)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.514  (1.410)
# rix:3 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 29.734  (25.273)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.694  (9.987)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.298  (6.798)
#     ConDo Gaussian KLD rMSE: 3.021  (2.887)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.593  (4.823)
# rix:3 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 20.200  (13.600)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.469  (4.828)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 11.487  (7.180)
#     ConDo Gaussian KLD rMSE: 8.740  (5.449)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.367  (3.261)
# rix:3 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.534  (24.339)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.170  (16.508)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.512  (5.362)
#     ConDo Gaussian KLD rMSE: 4.664  (3.446)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.944  (2.504)
# rix:3 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.736  (22.873)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.265  (11.998)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.909  (7.538)
#     ConDo Gaussian KLD rMSE: 5.577  (4.021)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.786  (2.611)
# rix:3 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.502  (15.503)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.523  (4.798)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 10.084  (8.386)
#     ConDo Gaussian KLD rMSE: 6.604  (5.572)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.946  (3.573)
# rix:4 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.534  (23.611)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.423  (17.794)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.495  (4.956)
#     ConDo Gaussian KLD rMSE: 0.508  (1.120)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.517  (0.918)
# rix:4 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.818  (24.638)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.792  (10.733)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.466  (7.181)
#     ConDo Gaussian KLD rMSE: 1.387  (1.488)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.457  (1.493)
# rix:4 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.097  (13.463)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.582  (3.795)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.605  (6.131)
#     ConDo Gaussian KLD rMSE: 2.324  (2.222)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.276  (1.553)
# rix:4 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.553  (23.995)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.638  (16.972)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 6.135  (5.643)
#     ConDo Gaussian KLD rMSE: 0.845  (1.072)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.977  (0.963)
# rix:4 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.096  (24.126)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.950  (11.411)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.410  (7.386)
#     ConDo Gaussian KLD rMSE: 2.254  (1.839)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.295  (1.738)
# rix:4 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 19.094  (13.350)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.202  (3.967)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.951  (5.888)
#     ConDo Gaussian KLD rMSE: 2.804  (2.190)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.916  (1.897)
# rix:4 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.112  (23.746)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.711  (16.235)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.553  (5.365)
#     ConDo Gaussian KLD rMSE: 1.360  (1.341)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.279  (1.153)
# rix:4 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 31.153  (24.650)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.308  (10.962)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.302  (6.651)
#     ConDo Gaussian KLD rMSE: 1.149  (1.345)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.419  (1.444)
# rix:4 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.104  (15.042)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.957  (4.349)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.254  (7.208)
#     ConDo Gaussian KLD rMSE: 2.976  (2.662)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.028  (3.249)
# rix:4 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.556  (23.629)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.524  (19.166)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.856  (5.310)
#     ConDo Gaussian KLD rMSE: 1.497  (1.396)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.231  (1.250)
# rix:4 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.355  (24.519)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.587  (10.616)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.775  (7.005)
#     ConDo Gaussian KLD rMSE: 2.005  (1.666)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.787  (1.670)
# rix:4 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.465  (14.385)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.333  (3.642)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.875  (6.636)
#     ConDo Gaussian KLD rMSE: 5.167  (3.994)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.082  (3.723)
# rix:4 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.123  (23.473)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.724  (17.492)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 4.877  (4.858)
#     ConDo Gaussian KLD rMSE: 2.230  (1.833)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.565  (2.109)
# rix:4 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 29.844  (24.952)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.718  (9.836)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.380  (6.791)
#     ConDo Gaussian KLD rMSE: 2.600  (2.581)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.838  (4.122)
# rix:4 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 20.031  (13.923)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.513  (4.955)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 11.356  (7.406)
#     ConDo Gaussian KLD rMSE: 8.976  (5.881)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.365  (3.430)
# rix:4 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.280  (24.454)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.932  (16.588)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 4.893  (4.692)
#     ConDo Gaussian KLD rMSE: 5.245  (4.014)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.515  (2.193)
# rix:4 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.763  (23.190)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.261  (12.407)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.740  (7.491)
#     ConDo Gaussian KLD rMSE: 4.869  (3.566)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.403  (2.390)
# rix:4 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.705  (15.266)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.600  (4.855)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 10.352  (8.342)
#     ConDo Gaussian KLD rMSE: 6.500  (5.349)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.705  (3.964)
# rix:5 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.422  (23.846)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.307  (17.616)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.383  (4.932)
#     ConDo Gaussian KLD rMSE: 0.495  (1.107)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.502  (0.911)
# rix:5 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 32.057  (24.656)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.129  (11.245)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.589  (7.326)
#     ConDo Gaussian KLD rMSE: 1.471  (1.466)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.399  (1.399)
# rix:5 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.183  (13.090)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.610  (3.751)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.650  (5.914)
#     ConDo Gaussian KLD rMSE: 2.213  (2.173)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.218  (1.488)
# rix:5 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.376  (24.053)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.557  (17.023)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.962  (5.550)
#     ConDo Gaussian KLD rMSE: 0.803  (1.057)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.877  (0.944)
# rix:5 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.456  (24.345)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.923  (11.160)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.215  (7.206)
#     ConDo Gaussian KLD rMSE: 2.057  (1.737)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.155  (1.644)
# rix:5 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.867  (13.378)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.986  (3.855)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.836  (5.920)
#     ConDo Gaussian KLD rMSE: 2.762  (2.196)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.722  (1.800)
# rix:5 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.132  (23.821)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.865  (16.562)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.815  (5.577)
#     ConDo Gaussian KLD rMSE: 1.254  (1.304)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.122  (1.111)
# rix:5 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 31.065  (24.356)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.227  (11.001)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.227  (6.552)
#     ConDo Gaussian KLD rMSE: 1.299  (1.383)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.285  (1.368)
# rix:5 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
# ...
#     Gaussian OT rMSE: 9.172  (16.901)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.387  (5.111)
#     ConDo Gaussian KLD rMSE: 0.772  (1.066)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.803  (0.930)
# rix:8 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.168  (24.392)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.469  (11.037)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.564  (6.754)
#     ConDo Gaussian KLD rMSE: 1.847  (1.616)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.700  (1.446)
# rix:8 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.306  (13.431)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.386  (3.540)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.104  (5.662)
#     ConDo Gaussian KLD rMSE: 2.504  (2.139)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.361  (1.648)
# rix:8 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.265  (23.678)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.834  (16.930)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.432  (5.120)
#     ConDo Gaussian KLD rMSE: 1.201  (1.253)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.061  (1.055)
# rix:8 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 30.928  (24.382)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.257  (11.362)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.019  (6.489)
#     ConDo Gaussian KLD rMSE: 1.414  (1.464)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.424  (1.439)
# rix:8 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 18.674  (14.314)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.837  (4.047)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.975  (6.671)
#     ConDo Gaussian KLD rMSE: 3.386  (2.705)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.454  (3.277)
# rix:8 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.356  (23.900)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.269  (18.140)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.794  (5.375)
#     ConDo Gaussian KLD rMSE: 1.553  (1.459)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.149  (1.137)
# rix:8 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.099  (24.325)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.475  (10.467)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.763  (6.975)
#     ConDo Gaussian KLD rMSE: 1.768  (1.593)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.725  (1.587)
# rix:8 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.723  (14.233)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.928  (4.076)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.786  (7.102)
#     ConDo Gaussian KLD rMSE: 5.128  (3.873)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.504  (3.935)
# rix:8 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.206  (23.642)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.880  (17.302)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.410  (5.047)
#     ConDo Gaussian KLD rMSE: 2.006  (1.699)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.615  (2.214)
# rix:8 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 30.663  (25.140)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.075  (10.181)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.657  (6.977)
#     ConDo Gaussian KLD rMSE: 2.560  (2.428)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.084  (3.417)
# rix:8 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 19.115  (14.302)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.192  (4.260)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.795  (6.973)
#     ConDo Gaussian KLD rMSE: 7.182  (5.170)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.736  (4.169)
# rix:8 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.546  (24.282)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.285  (17.059)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.582  (5.275)
#     ConDo Gaussian KLD rMSE: 4.626  (3.492)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.936  (2.532)
# rix:8 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.611  (23.965)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.111  (11.969)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.599  (7.500)
#     ConDo Gaussian KLD rMSE: 5.446  (4.055)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.898  (2.920)
# rix:8 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.411  (14.580)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.655  (4.101)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.130  (7.069)
#     ConDo Gaussian KLD rMSE: 6.411  (5.029)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.771  (3.020)
# rix:9 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.421  (24.084)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.269  (17.166)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.649  (5.251)
#     ConDo Gaussian KLD rMSE: 0.535  (1.091)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.590  (0.891)
# rix:9 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.923  (24.490)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.944  (11.300)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.445  (7.309)
#     ConDo Gaussian KLD rMSE: 1.305  (1.424)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.188  (1.277)
# rix:9 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.088  (13.100)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.573  (3.720)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.746  (6.057)
#     ConDo Gaussian KLD rMSE: 2.071  (2.071)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.713  (1.154)
# rix:9 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.376  (24.029)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.180  (17.164)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.462  (5.180)
#     ConDo Gaussian KLD rMSE: 0.755  (1.075)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 0.873  (0.964)
# rix:9 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.155  (24.292)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.526  (11.120)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.646  (6.813)
#     ConDo Gaussian KLD rMSE: 1.741  (1.576)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.685  (1.422)
# rix:9 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.199  (13.200)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.243  (3.525)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.981  (5.519)
#     ConDo Gaussian KLD rMSE: 2.415  (2.117)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.333  (1.606)
# rix:9 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.348  (23.726)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.890  (17.181)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.377  (5.081)
#     ConDo Gaussian KLD rMSE: 1.133  (1.237)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.032  (1.036)
# rix:9 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 30.847  (24.502)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.307  (11.315)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.183  (6.631)
#     ConDo Gaussian KLD rMSE: 1.535  (1.544)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.629  (1.583)
# rix:9 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 18.516  (14.302)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.614  (3.902)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.659  (6.480)
#     ConDo Gaussian KLD rMSE: 3.217  (2.627)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 4.146  (3.067)
# rix:9 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.364  (23.929)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.225  (18.193)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.554  (5.085)
#     ConDo Gaussian KLD rMSE: 1.510  (1.421)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.142  (1.115)
# rix:9 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.139  (24.351)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.518  (10.434)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.813  (7.000)
#     ConDo Gaussian KLD rMSE: 1.763  (1.575)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 1.781  (1.653)
# rix:9 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.856  (14.222)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.992  (4.145)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.958  (7.167)
#     ConDo Gaussian KLD rMSE: 5.403  (4.018)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.324  (3.795)
# rix:9 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.199  (23.579)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.954  (17.429)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.520  (5.174)
#     ConDo Gaussian KLD rMSE: 2.011  (1.681)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.652  (2.200)
# rix:9 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 30.736  (25.177)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.158  (10.340)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 7.641  (6.976)
#     ConDo Gaussian KLD rMSE: 2.846  (2.610)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.732  (3.176)
# rix:9 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 18.971  (14.181)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.256  (4.272)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.813  (6.985)
#     ConDo Gaussian KLD rMSE: 6.926  (4.996)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.568  (4.047)
# rix:9 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.580  (24.269)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.263  (17.013)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 5.513  (5.229)
#     ConDo Gaussian KLD rMSE: 4.522  (3.399)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 2.886  (2.512)
# rix:9 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.410  (24.037)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.968  (11.863)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 8.397  (7.375)
#     ConDo Gaussian KLD rMSE: 5.252  (3.935)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 5.360  (4.181)
# rix:9 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.518  (14.377)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.811  (4.152)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     MMD rMSE: 9.351  (7.031)
#     ConDo Gaussian KLD rMSE: 6.123  (4.756)
# n_batches: 13 dataset_size:(100, 20, 1)
# MMD sample shapes torch.Size([8, 20, 1]) torch.Size([8, 20, 1])
#     ConDo MMD rMSE: 3.438  (2.764)

# %%
methods = [
    "true (unobserved)",
    "batch-effected",
    "Gaussian OT",
    "MMD",
    "ConDo Gaussian KLD", 
    "ConDo MMD",
]
print_methods = [f"source - {meth}" for meth in methods]
num_multivars = len(multivar_settings)
multivars_np = np.array([int(mv) for mv in multivar_settings])
for prob_setting in prob_settings:
    fig = plt.figure(dpi=150, figsize=(3, 2))
    #for _ in range(2):
    #    # skip target, source-true
    #    next(plt.gca()._get_lines.prop_cycler)

    # skip true (always 0)
    for method in methods[1:]:
        # generate np.array of size (num_multivars, num_random)
        plot_rmses = -1 * np.ones((num_multivars, num_random))
        for mvix, mv_setting in enumerate(multivar_settings):
            sstr = f"{noise_setting}-{targetshift_setting}-{featureshift_setting}-{mv_setting}"
            for rix in range(num_random):
                plot_rmses[mvix, :] = np.array(rMSEs[sstr][method][prob_setting])
        plt.errorbar(
            multivars_np,
            np.mean(plot_rmses, axis=1),
            yerr=np.minimum(25, np.std(plot_rmses, axis=1)), marker='x');
    plt.ylabel('rMSE');
    plt.xlabel('# confounders');
    plt.xscale('log');
    plt.xticks([int(mv) for mv in multivar_settings], multivar_settings);
    plt.legend(
        print_methods[1:],
        title='', loc="center left", bbox_to_anchor=(1.05, 0.5),
        frameon=False,
    );
    plt.gca().set_ylim(-1, 35);
    figname = f"figure-continuous1d-split-{prob_setting}-rmses-{num_random}.pdf"
    #fig.savefig(figname, bbox_inches="tight")
for prob_setting in prob_settings:
    fig = plt.figure(dpi=150, figsize=(3, 2))
    #for _ in range(2):
    #    # skip target, source-true
    #    next(plt.gca()._get_lines.prop_cycler)

    # skip true (always 0)
    for method in methods[1:]:
        # generate np.array of size (num_multivars, num_random)
        plot_rmses = -1 * np.ones((num_multivars, num_random))
        for mvix, mv_setting in enumerate(multivar_settings):
            sstr = f"{noise_setting}-{targetshift_setting}-{featureshift_setting}-{mv_setting}"
            for rix in range(num_random):
                plot_rmses[mvix, :] = np.array(rMSEs_test[sstr][method][prob_setting])
        plt.errorbar(
            multivars_np,
            np.mean(plot_rmses, axis=1),
            yerr=np.minimum(35, np.std(plot_rmses, axis=1)), marker='x');
    plt.ylabel('rMSE');
    plt.xlabel('# confounders');
    plt.xscale('log');
    plt.xticks([int(mv) for mv in multivar_settings], multivar_settings);
    plt.legend(
        print_methods[1:],
        title='', loc="center left", bbox_to_anchor=(1.05, 0.5),
        frameon=False,
    );
    plt.gca().set_ylim(-1, 35);
    figname = f"figure-continuous1d-split-{prob_setting}-rmsestest-{num_random}.pdf"
    #fig.savefig(figname, bbox_inches="tight")

# %%
methods = [
    "true (unobserved)",
    "batch-effected",
    "Gaussian OT",
    "MMD",
    "ConDo Gaussian KLD", 
    "ConDo MMD",
]
mcolors = ["blue", "red", "cyan", "magenta"]
print_methods = [f"source - {meth}" for meth in methods]
num_multivars = len(multivar_settings)
multivars_np = np.array([int(mv) for mv in multivar_settings])
fig, axes = plt.subplots(
    dpi=150, nrows=1, ncols=len(prob_settings), figsize=(7, 2), sharey=False)
for probix, prob_setting in enumerate(prob_settings):
    for mix, method, mcolor in zip(range(len(mcolors)), methods[2:], mcolors):
        # generate np.array of size (num_multivars, num_random)
        plot_rmses = -1 * np.ones((num_multivars, num_random))
        for mvix, mv_setting in enumerate(multivar_settings):
            sstr = f"{noise_setting}-{targetshift_setting}-{featureshift_setting}-{mv_setting}"
            for rix in range(num_random):
                plot_rmses[mvix, :] = np.array(rMSEs[sstr][method][prob_setting])
        axes[probix].errorbar(
            multivars_np,
            np.mean(plot_rmses, axis=1),
            yerr=np.minimum(1, np.std(plot_rmses, axis=1)),
            marker='x', color=mcolor);
    if probix == 0:
        axes[probix].set_ylabel('rMSE');
    axes[probix].set_xlabel('# confounders');
    axes[probix].set_xscale('log');
    axes[probix].set_xticks([int(mv) for mv in multivar_settings], multivar_settings);
    axes[probix].set_yticks([0, 10]);
    axes[probix].minorticks_off()
plt.legend(
    print_methods[2:],
    title='', loc="center left", bbox_to_anchor=(1.05, 0.5),
    frameon=False,
);
plt.tight_layout();
figname = f"figure-continuous1d-split-rmses-{num_random}.pdf"
fig.savefig(figname, bbox_inches="tight")

fig, axes = plt.subplots(
    dpi=150, nrows=1, ncols=len(prob_settings), figsize=(7, 2), sharey=False)
for probix, prob_setting in enumerate(prob_settings):
    for mix, method, mcolor in zip(range(len(mcolors)), methods[2:], mcolors):
        # generate np.array of size (num_multivars, num_random)
        plot_rmses = -1 * np.ones((num_multivars, num_random))
        for mvix, mv_setting in enumerate(multivar_settings):
            sstr = f"{noise_setting}-{targetshift_setting}-{featureshift_setting}-{mv_setting}"
            for rix in range(num_random):
                plot_rmses[mvix, :] = np.array(rMSEs_test[sstr][method][prob_setting])
        axes[probix].errorbar(
            multivars_np,
            np.mean(plot_rmses, axis=1),
            yerr=np.minimum(1, np.std(plot_rmses, axis=1)),
            marker='x', color=mcolor);
    if probix == 0:
        axes[probix].set_ylabel('rMSE');
    axes[probix].set_xlabel('# confounders');
    axes[probix].set_xscale('log');
    axes[probix].set_xticks([int(mv) for mv in multivar_settings], multivar_settings);
    axes[probix].set_yticks([0, 10]);
    axes[probix].minorticks_off()
plt.legend(
    print_methods[2:],
    title='', loc="center left", bbox_to_anchor=(1.05, 0.5),
    frameon=False,
);
plt.tight_layout();
figname = f"figure-continuous1d-split-rmsestest-{num_random}.pdf"
fig.savefig(figname, bbox_inches="tight")

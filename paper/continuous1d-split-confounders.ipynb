# %%
from collections import defaultdict
from itertools import product

import matplotlib.pyplot as plt
import numpy as np
import ot
import seaborn as sns
import time
import warnings

import condo

# %%
plt.rcParams["xtick.major.size"] = 2
plt.rcParams["ytick.major.size"] = 2
plt.rcParams['axes.linewidth'] = 0.5
plt.rc('font', size=7) #controls default text size
plt.rc('axes', titlesize=7) #fontsize of the title
plt.rc('axes', labelsize=7) #fontsize of the x and y labels
plt.rc('xtick', labelsize=7) #fontsize of the x tick labels
plt.rc('ytick', labelsize=7) #fontsize of the y tick labels
plt.rc('legend', fontsize=7) #fontsize of the legend
plt.ioff();

# %%
def split_sum(arr, num_cols, rng):
    N, M = arr.shape
    assert np.min(arr) > 0
    assert M == 1
    newarr = np.zeros((N, num_cols))
    for i in range(N):
        total = arr[i, 0]
        dividers = sorted(rng.uniform(0, total, size=(num_cols-1,)))
        newarr[i, :] = np.array(
            [a - b for a, b in zip(dividers + [total], [0] + dividers)]
        ).reshape(1, -1)
    return newarr

# %%
N_T = 200
N_S = 100

# How batch effect affects S
batch_m = 2
batch_b = 5

# The true batch correction from Sbatch to S
true_m = 1. / batch_m
true_b = -1 * batch_b / batch_m

noise_settings = ["NoiseFree"]
targetshift_settings = ["TargetShift"]
featureshift_settings = ["FeatureShift"]
multivar_settings = ["1", "2", "4", "8", "16", "32"]

prob_settings = ["Homoscedastic Linear", "Heteroscedastic Linear", "Nonlinear"]
num_probs = len(prob_settings)

# method -> (num_Ns, num_random) array
rMSEs = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
rMSEs_test = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
num_random = 10
for rix in range(num_random):
    rng = np.random.RandomState(rix)
    for setting_combo in product(noise_settings, targetshift_settings, featureshift_settings, multivar_settings):
        (noise_setting, targetshift_setting, featureshift_setting, multivar_setting) = setting_combo
        setting_str = "-".join(setting_combo)
        assert noise_setting in ("Noisy", "NoiseFree")
        assert targetshift_setting in ("NoTargetShift", "TargetShift")
        assert featureshift_setting in ("NoFeatureShift", "FeatureShift")
        num_c = int(multivar_setting)

        fig, axes = plt.subplots(
            nrows=7, ncols=num_probs, sharex="all", sharey="all", squeeze=False,
            gridspec_kw={"hspace": 0.03, "wspace": 0.03},
            figsize=(6, 10), dpi=150)
        msize = 1
        basic_leg = ['target', 'source: batch-effected', 'source: true (unobserved)']
        figname = f"figure-continuous1d-split-{setting_str}-{rix}.pdf"
        fsizemse = 7

        for pix, prob_setting in enumerate(prob_settings):
            print(f"rix:{rix} {setting_str} {prob_setting}")
            # Distribution of confounders
            X_T = np.sort(rng.uniform(0, 8, size=(N_T,)))
            if targetshift_setting == "TargetShift":
                X_S = np.sort(rng.uniform(4, 8, size=(N_S,)))
                X_S_test = np.sort(rng.uniform(0, 8, size=(N_S,)))
            elif targetshift_setting == "NoTargetShift":
                X_S = np.sort(rng.uniform(0, 8, size=(N_S,)))
                X_S_test = np.sort(rng.uniform(0, 8, size=(N_S,)))
            
            if prob_setting == "Homoscedastic Linear":
                # How confounder X affects the distribution of T and S
                theta_m = 4
                theta_b = 1
                phi_m = 0
                phi_b = 2
                mu_T = theta_m * X_T + theta_b
                mu_S = theta_m * X_S + theta_b
                mu_S_test = theta_m * X_S_test + theta_b
                sigma_T = phi_m * X_T + phi_b
                sigma_S = phi_m * X_S + phi_b
                sigma_S_test = phi_m * X_S_test + phi_b
                T = rng.normal(mu_T, sigma_T)
                Strue = rng.normal(mu_S, sigma_S)
                Strue_test = rng.normal(mu_S_test, sigma_S_test)
            elif prob_setting == "Heteroscedastic Linear":
                # How confounder X affects the distribution of T and S
                theta_m = 4
                theta_b = 1
                phi_m = 1
                phi_b = 1
                mu_T = theta_m * X_T + theta_b
                mu_S = theta_m * X_S + theta_b
                mu_S_test = theta_m * X_S_test + theta_b
                sigma_T = phi_m * X_T + phi_b
                sigma_S = phi_m * X_S + phi_b
                sigma_S_test = phi_m * X_S_test + phi_b
                T = rng.normal(mu_T, sigma_T)
                Strue = rng.normal(mu_S, sigma_S)
                Strue_test = rng.normal(mu_S_test, sigma_S_test)
            elif prob_setting == "Nonlinear":
                # How confounder X affects the distribution of T and S
                theta_m = 4
                theta_b = 1
                phi_m = 1
                phi_b = 1
                mu_T = theta_m * (np.maximum(X_T-5, 0) ** 2) + theta_b
                mu_S = theta_m * (np.maximum(X_S-5, 0) ** 2) + theta_b
                mu_S_test = theta_m * (np.maximum(X_S_test-5, 0) ** 2) + theta_b
                sigma_T = phi_m * (np.maximum(X_T-5, 0) ** 2) + phi_b
                sigma_S = phi_m * (np.maximum(X_S-5, 0) ** 2) + phi_b
                sigma_S_test = phi_m * (np.maximum(X_S_test-5, 0) ** 2) + phi_b
                T = rng.normal(mu_T, sigma_T)
                Strue = rng.normal(mu_S, sigma_S)
                Strue_test = rng.normal(mu_S_test, sigma_S_test)
            if featureshift_setting == "FeatureShift":
                Sbatch = batch_m * Strue + batch_b
                Sbatch_test = batch_m * Strue_test + batch_b
                oracle_m = true_m
                oracle_b = true_b
            elif featureshift_setting == "NoFeatureShift":
                oracle_m = 1.0
                oracle_b = 0.0
                Sbatch = Strue.copy()
                Sbatch_test = Strue_test.copy()

            if noise_setting == "NoiseFree":
                pass
            elif noise_setting == "Noisy":
                Sbatch = Sbatch + rng.normal(0, 1, size=(N_S,))
                Sbatch_test = Sbatch_test + rng.normal(0, 1, size=(N_S,))

            T_ = T.reshape(-1, 1) # (N_T, 1)
            Strue_ = Strue.reshape(-1, 1) # (N_S, 1)
            Sbatch_ = Sbatch.reshape(-1, 1)
            X_T_ = X_T.reshape(-1, 1) # (N_T, 1)
            X_S_ = X_S.reshape(-1, 1)
            Strue_test_ = Strue_test.reshape(-1, 1) # (N_S, 1)
            Sbatch_test_ = Sbatch_test.reshape(-1, 1)
            X_S_test_ = X_S_test.reshape(-1, 1)
            
            # Before correction
            method = "batch-effected"
            rMSE = np.sqrt(np.mean((Sbatch - Strue) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sbatch_test - Strue_test) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[0, pix].tick_params(axis="both", which="both", direction="in")    
            axes[0, pix].scatter(X_T, T, s=msize)
            axes[0, pix].scatter(X_S, Sbatch, s=msize)
            axes[0, pix].scatter(X_S, Strue, s=msize)
            axes[0, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[0, pix].transAxes);
            if pix == num_probs - 1:
                axes[0, pix].legend(
                    basic_leg,
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            # Oracle - not displayed
            method = "Oracle"
            Soracle = oracle_m * Sbatch + oracle_b
            Soracle_test = oracle_m * Sbatch_test + oracle_b
            rMSE = np.sqrt(np.mean((Soracle - Strue) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Soracle_test - Strue_test) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")

            # OTDA
            method = "Gaussian OT"
            A_otda, b_otda = ot.da.OT_mapping_linear(Sbatch_, T_)
            Sotda_ = Sbatch_.dot(A_otda) + b_otda
            Sotda_test_ = Sbatch_test_.dot(A_otda) + b_otda
            rMSE = np.sqrt(np.mean((Sotda_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sotda_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[1, pix].tick_params(axis="both", which="both", direction="in")    
            axes[1, pix].scatter(X_T, T, s=msize)
            axes[1, pix].scatter(X_S, Sbatch, s=msize)
            axes[1, pix].scatter(X_S, Strue, s=msize)
            axes[1, pix].scatter(X_S, Sotda_, s=msize)
            axes[1, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[1, pix].transAxes);
            if pix == num_probs - 1:
                axes[1, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            # MMD
            method = "MMD"
            mmd_alpha = 0.01
            if prob_setting == "Nonlinear":
                mmd_alpha = 0.01
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                cder = condo.MMDAdapter(
                    transform_type="location-scale",
                    optim_kwargs={"epochs": 50, "alpha": mmd_alpha, "beta": 0.9},
                    debug=False,
                    verbose=0,
                )
                cder.fit(Sbatch_, T_)
                Smmd_ = cder.transform(Sbatch_)
                Smmd_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Smmd_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Smmd_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting]);
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[2, pix].tick_params(axis="both", which="both", direction="in")    
            axes[2, pix].scatter(X_T, T, s=msize)
            axes[2, pix].scatter(X_S, Sbatch, s=msize)
            axes[2, pix].scatter(X_S, Strue, s=msize)
            axes[2, pix].scatter(X_S, Smmd_, s=msize)
            axes[2, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[2, pix].transAxes);
            if pix == num_probs - 1:
                axes[2, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            # ConDo using ReverseKL with linear Gaussian
            method = "ConDo Linear-ReverseKL"
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                cder = condo.ConDoAdapter(
                    sampling="product",
                    transform_type="location-scale",
                    model_type="linear",
                    divergence="reverse",
                    debug=False,
                    verbose=0
                )
                cder.fit(Sbatch_, T_, split_sum(X_S_, num_c, rng), split_sum(X_T_, num_c, rng))
                Sreverse_ = cder.transform(Sbatch_)
                Sreverse_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Sreverse_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sreverse_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[3, pix].tick_params(axis="both", which="both", direction="in")    
            axes[3, pix].scatter(X_T, T, s=msize)
            axes[3, pix].scatter(X_S, Sbatch, s=msize)
            axes[3, pix].scatter(X_S, Strue, s=msize)
            axes[3, pix].scatter(X_S, Sreverse_, s=msize)
            axes[3, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[3, pix].transAxes);
            if pix == num_probs - 1:
                axes[3, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);            

            # ConDo using ReverseKL with heteroscedastic GP
            method = "ConDo GP-ReverseKL"
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                cder = condo.ConDoAdapter(
                    sampling="product",
                    transform_type="location-scale",
                    model_type="heteroscedastic-gp",
                    divergence="reverse",
                    debug=False,
                    verbose=0
                )
                cder.fit(Sbatch_, T_, split_sum(X_S_, num_c, rng), split_sum(X_T_, num_c, rng))
                Sreverse_ = cder.transform(Sbatch_)
                Sreverse_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Sreverse_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sreverse_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[4, pix].tick_params(axis="both", which="both", direction="in")    
            axes[4, pix].scatter(X_T, T, s=msize)
            axes[4, pix].scatter(X_S, Sbatch, s=msize)
            axes[4, pix].scatter(X_S, Strue, s=msize)
            axes[4, pix].scatter(X_S, Sreverse_, s=msize)
            axes[4, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[4, pix].transAxes);
            if pix == num_probs - 1:
                axes[4, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            # ConDo using ReverseKL with product-of-GMMs
            method = "ConDo PoGMM-ReverseKL"
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                cder = condo.ConDoAdapter(
                    sampling="product",
                    transform_type="location-scale",
                    model_type="pogmm",
                    divergence="reverse",
                    debug=False,
                    verbose=0
                )
                cder.fit(Sbatch_, T_, split_sum(X_S_, num_c, rng), split_sum(X_T_, num_c, rng))
                Sreverse_ = cder.transform(Sbatch_)
                Sreverse_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Sreverse_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Sreverse_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting])
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[5, pix].tick_params(axis="both", which="both", direction="in")    
            axes[5, pix].scatter(X_T, T, s=msize)
            axes[5, pix].scatter(X_S, Sbatch, s=msize)
            axes[5, pix].scatter(X_S, Strue, s=msize)
            axes[5, pix].scatter(X_S, Sreverse_, s=msize)
            axes[5, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f} ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[5, pix].transAxes);
            if pix == num_probs - 1:
                axes[5, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);

            # Condo using MMD
            method = "ConDo MMD"
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                cder = condo.ConDoAdapter(
                    sampling="product",
                    transform_type="location-scale",
                    model_type="empirical",
                    divergence="mmd",
                    optim_kwargs={"epochs": 25, "alpha": 0.01, "beta": 0.9},
                    debug=False,
                    verbose=0,
                )
                cder.fit(Sbatch_, T_, split_sum(X_S_, num_c, rng), split_sum(X_T_, num_c, rng))
                Smmd_ = cder.transform(Sbatch_)
                Smmd_test_ = cder.transform(Sbatch_test_)
            rMSE = np.sqrt(np.mean((Smmd_ - Strue_) ** 2));
            rMSEs[setting_str][method][prob_setting].append(rMSE)
            rMSE_test = np.sqrt(np.mean((Smmd_test_ - Strue_test_) ** 2));
            rMSEs_test[setting_str][method][prob_setting].append(rMSE_test)
            avgrMSE = np.mean(rMSEs[setting_str][method][prob_setting])
            avgrMSE_test = np.mean(rMSEs_test[setting_str][method][prob_setting]);
            print(f"    {method} rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})")
            axes[6, pix].tick_params(axis="both", which="both", direction="in")    
            axes[6, pix].scatter(X_T, T, s=msize)
            axes[6, pix].scatter(X_S, Sbatch, s=msize)
            axes[6, pix].scatter(X_S, Strue, s=msize)
            axes[6, pix].scatter(X_S, Smmd_, s=msize)
            axes[6, pix].text(
                0.1, 0.9, f"rMSE: {avgrMSE:.3f}  ({avgrMSE_test:.3f})", size=fsizemse,
                transform = axes[6, pix].transAxes);
            if pix == num_probs - 1:
                axes[6, pix].legend(
                    basic_leg + [f"source: {method}"],
                    loc="center left", bbox_to_anchor=(1.05, 0.5),
                    frameon=False, borderpad=0.2, handlelength=0.3, borderaxespad=0.2);
        if rix in (0, num_random - 1):
            fig.savefig(figname, bbox_inches="tight")
        plt.close()
# Out:
# rix:0 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.110  (22.992)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.049  (17.721)
#     MMD rMSE: 7.083  (5.178)
#     ConDo Linear-ReverseKL rMSE: 0.474  (1.236)
#     ConDo GP-ReverseKL rMSE: 0.472  (1.234)
#     ConDo PoGMM-ReverseKL rMSE: 0.666  (1.131)
#     ConDo MMD rMSE: 2.586  (1.833)
# rix:0 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.425  (26.066)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.538  (11.201)
#     MMD rMSE: 14.285  (11.703)
#     ConDo Linear-ReverseKL rMSE: 0.731  (1.249)
#     ConDo GP-ReverseKL rMSE: 1.925  (2.078)
#     ConDo PoGMM-ReverseKL rMSE: 0.732  (1.258)
#     ConDo MMD rMSE: 3.073  (2.496)
# rix:0 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 17.877  (15.738)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.535  (4.148)
#     MMD rMSE: 7.093  (6.250)
#     ConDo Linear-ReverseKL rMSE: 2.458  (2.481)
#     ConDo GP-ReverseKL rMSE: 1.680  (1.905)
#     ConDo PoGMM-ReverseKL rMSE: 1.735  (1.944)
#     ConDo MMD rMSE: 4.722  (4.170)
# rix:0 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 29.973  (24.171)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.225  (17.023)
#     MMD rMSE: 3.641  (2.759)
#     ConDo Linear-ReverseKL rMSE: 0.458  (1.069)
#     ConDo GP-ReverseKL rMSE: 0.463  (1.108)
#     ConDo PoGMM-ReverseKL rMSE: 4.241  (3.205)
#     ConDo MMD rMSE: 6.009  (4.666)
# rix:0 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 32.182  (22.154)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.678  (12.435)
#     MMD rMSE: 9.959  (6.442)
#     ConDo Linear-ReverseKL rMSE: 2.488  (1.670)
#     ConDo GP-ReverseKL rMSE: 4.093  (2.523)
#     ConDo PoGMM-ReverseKL rMSE: 7.279  (4.513)
#     ConDo MMD rMSE: 9.474  (6.115)
# rix:0 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 20.578  (16.023)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.768  (6.247)
#     MMD rMSE: 20.578  (16.023)
#     ConDo Linear-ReverseKL rMSE: 8.379  (6.395)
#     ConDo GP-ReverseKL rMSE: 3.497  (2.885)
#     ConDo PoGMM-ReverseKL rMSE: 7.768  (5.939)
#     ConDo MMD rMSE: 11.125  (8.452)
# rix:0 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 31.483  (22.288)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 11.144  (20.973)
#     MMD rMSE: 9.289  (6.088)
#     ConDo Linear-ReverseKL rMSE: 0.707  (1.137)
#     ConDo GP-ReverseKL rMSE: 0.765  (1.131)
#     ConDo PoGMM-ReverseKL rMSE: 8.202  (5.239)
#     ConDo MMD rMSE: 10.946  (7.383)
# rix:0 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 29.446  (24.057)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.242  (11.208)
#     MMD rMSE: 8.972  (7.105)
#     ConDo Linear-ReverseKL rMSE: 0.842  (1.223)
#     ConDo GP-ReverseKL rMSE: 0.704  (1.228)
#     ConDo PoGMM-ReverseKL rMSE: 5.033  (3.974)
#     ConDo MMD rMSE: 7.596  (6.052)
# rix:0 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.536  (14.472)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.560  (4.426)
#     MMD rMSE: 19.536  (14.472)
#     ConDo Linear-ReverseKL rMSE: 6.429  (4.602)
#     ConDo GP-ReverseKL rMSE: 7.172  (5.109)
#     ConDo PoGMM-ReverseKL rMSE: 7.434  (5.291)
#     ConDo MMD rMSE: 7.641  (5.414)
# rix:0 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.634  (23.645)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.707  (18.332)
#     MMD rMSE: 7.905  (5.787)
#     ConDo Linear-ReverseKL rMSE: 1.412  (1.240)
#     ConDo GP-ReverseKL rMSE: 1.169  (1.154)
#     ConDo PoGMM-ReverseKL rMSE: 8.151  (5.878)
#     ConDo MMD rMSE: 13.398  (10.064)
# rix:0 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.182  (25.266)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.424  (11.610)
#     MMD rMSE: 8.866  (6.986)
#     ConDo Linear-ReverseKL rMSE: 2.760  (2.231)
#     ConDo GP-ReverseKL rMSE: 2.722  (2.205)
#     ConDo PoGMM-ReverseKL rMSE: 10.098  (7.897)
#     ConDo MMD rMSE: 14.621  (11.636)
# rix:0 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 20.196  (12.096)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.472  (4.670)
#     MMD rMSE: 20.196  (12.096)
#     ConDo Linear-ReverseKL rMSE: 11.377  (5.991)
#     ConDo GP-ReverseKL rMSE: 9.701  (5.093)
#     ConDo PoGMM-ReverseKL rMSE: 10.545  (5.544)
#     ConDo MMD rMSE: 8.722  (4.590)
# rix:0 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.214  (24.241)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.674  (17.067)
#     MMD rMSE: 3.937  (3.018)
#     ConDo Linear-ReverseKL rMSE: 1.783  (1.567)
#     ConDo GP-ReverseKL rMSE: 1.997  (1.692)
#     ConDo PoGMM-ReverseKL rMSE: 9.132  (7.036)
#     ConDo MMD rMSE: 15.954  (12.493)
# rix:0 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.458  (20.840)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.269  (13.125)
#     MMD rMSE: 7.482  (4.394)
#     ConDo Linear-ReverseKL rMSE: 9.346  (5.351)
#     ConDo GP-ReverseKL rMSE: 1.975  (1.183)
#     ConDo PoGMM-ReverseKL rMSE: 10.433  (6.034)
#     ConDo MMD rMSE: 16.211  (10.256)
# rix:0 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 17.110  (14.334)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.837  (3.628)
#     MMD rMSE: 8.551  (7.112)
#     ConDo Linear-ReverseKL rMSE: 6.924  (5.880)
#     ConDo GP-ReverseKL rMSE: 4.472  (3.922)
#     ConDo PoGMM-ReverseKL rMSE: 8.192  (6.908)
#     ConDo MMD rMSE: 5.412  (4.535)
# rix:0 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.537  (23.426)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.337  (17.423)
#     MMD rMSE: 7.758  (5.640)
#     ConDo Linear-ReverseKL rMSE: 2.768  (2.014)
#     ConDo GP-ReverseKL rMSE: 2.220  (1.680)
#     ConDo PoGMM-ReverseKL rMSE: 9.268  (6.688)
#     ConDo MMD rMSE: 276.188  (207.920)
# rix:0 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.438  (25.486)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.759  (8.431)
#     MMD rMSE: 1.632  (1.355)
#     ConDo Linear-ReverseKL rMSE: 0.764  (1.267)
#     ConDo GP-ReverseKL rMSE: 1.122  (1.540)
#     ConDo PoGMM-ReverseKL rMSE: 7.736  (6.012)
#     ConDo MMD rMSE: 0.768  (1.170)
# rix:0 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.682  (12.489)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.807  (4.134)
#     MMD rMSE: 18.682  (12.489)
#     ConDo Linear-ReverseKL rMSE: 6.574  (3.999)
#     ConDo GP-ReverseKL rMSE: 13.781  (8.415)
#     ConDo PoGMM-ReverseKL rMSE: 10.072  (6.110)
#     ConDo MMD rMSE: 1445.277  (921.942)
# rix:1 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.772  (23.538)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 10.009  (19.895)
#     MMD rMSE: 8.783  (6.410)
#     ConDo Linear-ReverseKL rMSE: 0.492  (1.151)
#     ConDo GP-ReverseKL rMSE: 0.512  (1.146)
#     ConDo PoGMM-ReverseKL rMSE: 0.866  (1.116)
#     ConDo MMD rMSE: 2.789  (1.959)
# rix:1 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.769  (25.719)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.086  (12.222)
#     MMD rMSE: 10.890  (8.688)
#     ConDo Linear-ReverseKL rMSE: 0.780  (1.231)
#     ConDo GP-ReverseKL rMSE: 1.401  (1.749)
#     ConDo PoGMM-ReverseKL rMSE: 0.936  (1.267)
#     ConDo MMD rMSE: 4.431  (3.433)
# rix:1 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 16.913  (12.670)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.223  (3.111)
#     MMD rMSE: 5.387  (4.039)
#     ConDo Linear-ReverseKL rMSE: 2.175  (2.319)
#     ConDo GP-ReverseKL rMSE: 1.780  (2.026)
#     ConDo PoGMM-ReverseKL rMSE: 1.962  (2.138)
#     ConDo MMD rMSE: 3.885  (2.851)
# rix:1 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.227  (24.198)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.651  (18.025)
#     MMD rMSE: 4.436  (3.344)
#     ConDo Linear-ReverseKL rMSE: 0.473  (1.075)
#     ConDo GP-ReverseKL rMSE: 0.483  (1.093)
#     ConDo PoGMM-ReverseKL rMSE: 4.332  (3.247)
#     ConDo MMD rMSE: 5.668  (4.353)
# rix:1 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.563  (24.016)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.403  (10.379)
#     MMD rMSE: 7.127  (4.942)
#     ConDo Linear-ReverseKL rMSE: 1.654  (1.442)
#     ConDo GP-ReverseKL rMSE: 2.960  (2.068)
#     ConDo PoGMM-ReverseKL rMSE: 5.919  (4.084)
#     ConDo MMD rMSE: 7.561  (5.338)
# rix:1 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 19.875  (15.559)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.819  (5.515)
#     MMD rMSE: 19.875  (15.559)
#     ConDo Linear-ReverseKL rMSE: 7.630  (5.880)
#     ConDo GP-ReverseKL rMSE: 3.061  (2.631)
#     ConDo PoGMM-ReverseKL rMSE: 7.271  (5.610)
#     ConDo MMD rMSE: 9.627  (7.355)
# rix:1 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.658  (23.058)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 10.096  (19.720)
#     MMD rMSE: 9.672  (6.907)
#     ConDo Linear-ReverseKL rMSE: 0.670  (1.102)
#     ConDo GP-ReverseKL rMSE: 0.724  (1.101)
#     ConDo PoGMM-ReverseKL rMSE: 6.817  (4.662)
#     ConDo MMD rMSE: 9.596  (6.884)
# rix:1 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 29.309  (25.588)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.503  (9.536)
#     MMD rMSE: 4.895  (4.069)
#     ConDo Linear-ReverseKL rMSE: 0.951  (1.280)
#     ConDo GP-ReverseKL rMSE: 0.923  (1.312)
#     ConDo PoGMM-ReverseKL rMSE: 4.340  (3.732)
#     ConDo MMD rMSE: 6.666  (5.696)
# rix:1 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.447  (14.248)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.233  (4.193)
#     MMD rMSE: 19.447  (14.248)
#     ConDo Linear-ReverseKL rMSE: 7.243  (4.968)
#     ConDo GP-ReverseKL rMSE: 7.755  (5.317)
#     ConDo PoGMM-ReverseKL rMSE: 7.337  (5.040)
#     ConDo MMD rMSE: 6.853  (4.738)
# rix:1 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.348  (23.452)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.984  (20.557)
#     MMD rMSE: 7.174  (5.269)
#     ConDo Linear-ReverseKL rMSE: 1.896  (1.525)
#     ConDo GP-ReverseKL rMSE: 1.550  (1.352)
#     ConDo PoGMM-ReverseKL rMSE: 8.233  (5.972)
#     ConDo MMD rMSE: 13.270  (9.978)
# rix:1 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.001  (25.900)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.640  (10.811)
#     MMD rMSE: 8.381  (6.835)
#     ConDo Linear-ReverseKL rMSE: 3.007  (2.528)
#     ConDo GP-ReverseKL rMSE: 2.128  (1.883)
#     ConDo PoGMM-ReverseKL rMSE: 8.856  (7.170)
#     ConDo MMD rMSE: 12.899  (10.580)
# rix:1 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 19.515  (12.804)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.337  (4.304)
#     MMD rMSE: 19.515  (12.804)
#     ConDo Linear-ReverseKL rMSE: 10.159  (5.982)
#     ConDo GP-ReverseKL rMSE: 8.564  (5.031)
#     ConDo PoGMM-ReverseKL rMSE: 9.917  (5.875)
#     ConDo MMD rMSE: 6.707  (3.864)
# rix:1 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.407  (25.177)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.783  (16.887)
#     MMD rMSE: 4.182  (3.323)
#     ConDo Linear-ReverseKL rMSE: 2.162  (1.838)
#     ConDo GP-ReverseKL rMSE: 2.557  (2.126)
#     ConDo PoGMM-ReverseKL rMSE: 9.300  (7.428)
#     ConDo MMD rMSE: 16.175  (13.132)
# rix:1 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.127  (22.097)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.596  (11.583)
#     MMD rMSE: 5.905  (3.700)
#     ConDo Linear-ReverseKL rMSE: 5.258  (3.290)
#     ConDo GP-ReverseKL rMSE: 2.085  (1.409)
#     ConDo PoGMM-ReverseKL rMSE: 9.858  (6.301)
#     ConDo MMD rMSE: 16.135  (11.077)
# rix:1 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 17.248  (14.282)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.494  (3.101)
#     MMD rMSE: 12.968  (10.671)
#     ConDo Linear-ReverseKL rMSE: 7.617  (6.210)
#     ConDo GP-ReverseKL rMSE: 7.718  (6.279)
#     ConDo PoGMM-ReverseKL rMSE: 7.529  (6.159)
#     ConDo MMD rMSE: 4.876  (3.976)
# rix:1 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.525  (23.090)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.238  (17.530)
#     MMD rMSE: 6.347  (4.518)
#     ConDo Linear-ReverseKL rMSE: 1.913  (1.598)
#     ConDo GP-ReverseKL rMSE: 2.205  (1.651)
#     ConDo PoGMM-ReverseKL rMSE: 9.164  (6.493)
#     ConDo MMD rMSE: 145.372  (109.216)
# rix:1 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.167  (24.189)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.704  (10.847)
#     MMD rMSE: 3.370  (2.407)
#     ConDo Linear-ReverseKL rMSE: 2.931  (2.338)
#     ConDo GP-ReverseKL rMSE: 1.656  (1.554)
#     ConDo PoGMM-ReverseKL rMSE: 8.827  (6.414)
#     ConDo MMD rMSE: 17712.321  (12846.890)
# rix:1 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 17.762  (13.070)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.467  (3.849)
#     MMD rMSE: 14.259  (10.173)
#     ConDo Linear-ReverseKL rMSE: 7.025  (5.029)
#     ConDo GP-ReverseKL rMSE: 12.723  (8.883)
#     ConDo PoGMM-ReverseKL rMSE: 9.230  (6.438)
#     ConDo MMD rMSE: 888.412  (593.671)
# rix:2 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.748  (23.089)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.964  (19.047)
#     MMD rMSE: 7.591  (5.429)
#     ConDo Linear-ReverseKL rMSE: 0.491  (1.174)
#     ConDo GP-ReverseKL rMSE: 0.520  (1.165)
#     ConDo PoGMM-ReverseKL rMSE: 0.913  (1.138)
#     ConDo MMD rMSE: 3.345  (2.289)
# rix:2 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.805  (25.496)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.254  (11.668)
#     MMD rMSE: 9.499  (7.480)
#     ConDo Linear-ReverseKL rMSE: 1.460  (1.560)
#     ConDo GP-ReverseKL rMSE: 1.600  (1.737)
#     ConDo PoGMM-ReverseKL rMSE: 1.702  (1.677)
#     ConDo MMD rMSE: 5.012  (3.840)
# rix:2 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.101  (13.251)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.036  (4.098)
#     MMD rMSE: 10.417  (7.498)
#     ConDo Linear-ReverseKL rMSE: 3.885  (3.118)
#     ConDo GP-ReverseKL rMSE: 2.393  (2.182)
#     ConDo PoGMM-ReverseKL rMSE: 2.542  (2.271)
#     ConDo MMD rMSE: 5.117  (3.541)
# rix:2 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.506  (23.905)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.867  (17.809)
#     MMD rMSE: 7.334  (5.340)
#     ConDo Linear-ReverseKL rMSE: 0.550  (1.046)
#     ConDo GP-ReverseKL rMSE: 0.536  (1.061)
#     ConDo PoGMM-ReverseKL rMSE: 4.950  (3.549)
#     ConDo MMD rMSE: 6.281  (4.668)
# rix:2 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.286  (24.591)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.087  (9.916)
#     MMD rMSE: 7.484  (5.533)
#     ConDo Linear-ReverseKL rMSE: 1.386  (1.396)
#     ConDo GP-ReverseKL rMSE: 2.317  (1.799)
#     ConDo PoGMM-ReverseKL rMSE: 5.573  (4.045)
#     ConDo MMD rMSE: 6.868  (5.047)
# rix:2 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.603  (14.278)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.115  (4.303)
#     MMD rMSE: 18.603  (14.278)
#     ConDo Linear-ReverseKL rMSE: 5.964  (4.618)
#     ConDo GP-ReverseKL rMSE: 2.732  (2.379)
#     ConDo PoGMM-ReverseKL rMSE: 5.496  (4.354)
#     ConDo MMD rMSE: 7.223  (5.445)
# rix:2 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.340  (23.482)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.802  (18.725)
#     MMD rMSE: 9.124  (6.724)
#     ConDo Linear-ReverseKL rMSE: 0.601  (1.102)
#     ConDo GP-ReverseKL rMSE: 0.675  (1.134)
#     ConDo PoGMM-ReverseKL rMSE: 6.508  (4.641)
#     ConDo MMD rMSE: 8.559  (6.312)
# rix:2 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 29.737  (25.509)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 6.941  (9.707)
#     MMD rMSE: 7.269  (5.958)
#     ConDo Linear-ReverseKL rMSE: 0.989  (1.278)
#     ConDo GP-ReverseKL rMSE: 1.745  (1.796)
#     ConDo PoGMM-ReverseKL rMSE: 5.157  (4.303)
#     ConDo MMD rMSE: 7.122  (5.966)
# rix:2 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.124  (15.147)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.434  (3.711)
#     MMD rMSE: 19.124  (15.147)
#     ConDo Linear-ReverseKL rMSE: 6.196  (4.646)
#     ConDo GP-ReverseKL rMSE: 6.929  (5.227)
#     ConDo PoGMM-ReverseKL rMSE: 6.589  (4.987)
#     ConDo MMD rMSE: 6.634  (5.079)
# rix:2 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.327  (22.713)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.711  (19.390)
#     MMD rMSE: 8.596  (6.044)
#     ConDo Linear-ReverseKL rMSE: 1.886  (1.496)
#     ConDo GP-ReverseKL rMSE: 1.528  (1.342)
#     ConDo PoGMM-ReverseKL rMSE: 8.142  (5.677)
#     ConDo MMD rMSE: 13.466  (9.757)
# rix:2 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.310  (25.711)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.651  (11.596)
#     MMD rMSE: 9.315  (7.430)
#     ConDo Linear-ReverseKL rMSE: 2.765  (2.305)
#     ConDo GP-ReverseKL rMSE: 1.783  (1.678)
#     ConDo PoGMM-ReverseKL rMSE: 8.644  (6.860)
#     ConDo MMD rMSE: 12.308  (9.948)
# rix:2 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 19.120  (12.419)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.573  (3.898)
#     MMD rMSE: 15.439  (9.916)
#     ConDo Linear-ReverseKL rMSE: 9.349  (5.412)
#     ConDo GP-ReverseKL rMSE: 8.463  (4.876)
#     ConDo PoGMM-ReverseKL rMSE: 9.089  (5.287)
#     ConDo MMD rMSE: 5.305  (3.037)
# rix:2 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.628  (24.380)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.536  (16.712)
#     MMD rMSE: 4.890  (3.633)
#     ConDo Linear-ReverseKL rMSE: 1.770  (1.601)
#     ConDo GP-ReverseKL rMSE: 2.368  (1.898)
#     ConDo PoGMM-ReverseKL rMSE: 9.227  (6.997)
#     ConDo MMD rMSE: 15.644  (12.244)
# rix:2 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 30.945  (23.333)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.424  (10.966)
#     MMD rMSE: 7.485  (5.424)
#     ConDo Linear-ReverseKL rMSE: 6.201  (4.440)
#     ConDo GP-ReverseKL rMSE: 1.818  (1.437)
#     ConDo PoGMM-ReverseKL rMSE: 9.634  (6.750)
#     ConDo MMD rMSE: 210.035  (174.457)
# rix:2 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 17.040  (14.986)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.297  (3.087)
#     MMD rMSE: 14.187  (12.578)
#     ConDo Linear-ReverseKL rMSE: 7.071  (6.229)
#     ConDo GP-ReverseKL rMSE: 8.306  (7.434)
#     ConDo PoGMM-ReverseKL rMSE: 7.281  (6.460)
#     ConDo MMD rMSE: 5.203  (4.658)
# rix:2 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.650  (23.495)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.438  (17.845)
#     MMD rMSE: 5.575  (4.011)
#     ConDo Linear-ReverseKL rMSE: 3.588  (2.785)
#     ConDo GP-ReverseKL rMSE: 2.957  (2.202)
#     ConDo PoGMM-ReverseKL rMSE: 9.436  (6.823)
#     ConDo MMD rMSE: 206.727  (158.030)
# rix:2 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 30.898  (24.276)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.502  (9.991)
#     MMD rMSE: 5.207  (3.905)
#     ConDo Linear-ReverseKL rMSE: 5.578  (4.368)
#     ConDo GP-ReverseKL rMSE: 2.372  (2.019)
#     ConDo PoGMM-ReverseKL rMSE: 8.770  (6.504)
#     ConDo MMD rMSE: 11838.482  (8588.569)
# rix:2 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.463  (13.466)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.116  (4.312)
#     MMD rMSE: 16.128  (11.535)
#     ConDo Linear-ReverseKL rMSE: 7.808  (5.470)
#     ConDo GP-ReverseKL rMSE: 13.484  (9.323)
#     ConDo PoGMM-ReverseKL rMSE: 9.916  (6.843)
#     ConDo MMD rMSE: 1461.210  (1001.324)
# rix:3 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.617  (23.198)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.692  (18.256)
#     MMD rMSE: 8.247  (5.973)
#     ConDo Linear-ReverseKL rMSE: 0.515  (1.152)
#     ConDo GP-ReverseKL rMSE: 0.570  (1.144)
#     ConDo PoGMM-ReverseKL rMSE: 0.955  (1.139)
#     ConDo MMD rMSE: 3.155  (2.181)
# rix:3 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.646  (25.257)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.900  (10.859)
#     MMD rMSE: 9.445  (7.363)
#     ConDo Linear-ReverseKL rMSE: 1.457  (1.518)
#     ConDo GP-ReverseKL rMSE: 1.420  (1.617)
#     ConDo PoGMM-ReverseKL rMSE: 1.709  (1.637)
#     ConDo MMD rMSE: 4.828  (3.674)
# rix:3 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 17.832  (13.148)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.691  (3.788)
#     MMD rMSE: 9.309  (6.711)
#     ConDo Linear-ReverseKL rMSE: 3.583  (2.921)
#     ConDo GP-ReverseKL rMSE: 2.285  (2.136)
#     ConDo PoGMM-ReverseKL rMSE: 2.366  (2.194)
#     ConDo MMD rMSE: 4.840  (3.385)
# rix:3 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.692  (23.959)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 10.032  (17.587)
#     MMD rMSE: 7.272  (5.312)
#     ConDo Linear-ReverseKL rMSE: 0.570  (1.047)
#     ConDo GP-ReverseKL rMSE: 0.583  (1.057)
#     ConDo PoGMM-ReverseKL rMSE: 5.204  (3.719)
#     ConDo MMD rMSE: 6.196  (4.584)
# rix:3 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.409  (24.137)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.529  (10.594)
#     MMD rMSE: 7.589  (5.460)
#     ConDo Linear-ReverseKL rMSE: 1.430  (1.367)
#     ConDo GP-ReverseKL rMSE: 1.948  (1.651)
#     ConDo PoGMM-ReverseKL rMSE: 6.064  (4.254)
#     ConDo MMD rMSE: 7.528  (5.389)
# rix:3 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.380  (13.777)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.762  (4.132)
#     MMD rMSE: 16.540  (12.402)
#     ConDo Linear-ReverseKL rMSE: 5.524  (4.202)
#     ConDo GP-ReverseKL rMSE: 2.528  (2.269)
#     ConDo PoGMM-ReverseKL rMSE: 5.096  (3.961)
#     ConDo MMD rMSE: 7.238  (5.275)
# rix:3 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.233  (23.422)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.176  (18.036)
#     MMD rMSE: 8.199  (6.045)
#     ConDo Linear-ReverseKL rMSE: 0.585  (1.121)
#     ConDo GP-ReverseKL rMSE: 0.674  (1.145)
#     ConDo PoGMM-ReverseKL rMSE: 5.883  (4.223)
#     ConDo MMD rMSE: 7.869  (5.815)
# rix:3 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 30.198  (24.466)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.148  (9.753)
#     MMD rMSE: 7.467  (5.680)
#     ConDo Linear-ReverseKL rMSE: 0.949  (1.326)
#     ConDo GP-ReverseKL rMSE: 1.510  (1.709)
#     ConDo PoGMM-ReverseKL rMSE: 5.471  (4.157)
#     ConDo MMD rMSE: 7.316  (5.698)
# rix:3 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 18.967  (14.453)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.549  (3.623)
#     MMD rMSE: 18.967  (14.453)
#     ConDo Linear-ReverseKL rMSE: 6.688  (4.688)
#     ConDo GP-ReverseKL rMSE: 7.385  (5.212)
#     ConDo PoGMM-ReverseKL rMSE: 6.648  (4.746)
#     ConDo MMD rMSE: 6.563  (4.750)
# rix:3 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.400  (22.938)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.471  (18.609)
#     MMD rMSE: 7.287  (5.140)
#     ConDo Linear-ReverseKL rMSE: 1.553  (1.400)
#     ConDo GP-ReverseKL rMSE: 1.311  (1.281)
#     ConDo PoGMM-ReverseKL rMSE: 7.846  (5.507)
#     ConDo MMD rMSE: 13.109  (9.575)
# rix:3 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.102  (25.417)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.839  (11.989)
#     MMD rMSE: 8.551  (6.792)
#     ConDo Linear-ReverseKL rMSE: 2.671  (2.227)
#     ConDo GP-ReverseKL rMSE: 1.888  (1.728)
#     ConDo PoGMM-ReverseKL rMSE: 8.861  (6.994)
#     ConDo MMD rMSE: 13.041  (10.481)
# rix:3 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.534  (13.334)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.262  (3.961)
#     MMD rMSE: 15.774  (11.457)
#     ConDo Linear-ReverseKL rMSE: 9.120  (6.108)
#     ConDo GP-ReverseKL rMSE: 8.624  (5.867)
#     ConDo PoGMM-ReverseKL rMSE: 8.699  (5.797)
#     ConDo MMD rMSE: 4.182  (2.473)
# rix:3 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.807  (24.435)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.401  (16.396)
#     MMD rMSE: 5.603  (4.167)
#     ConDo Linear-ReverseKL rMSE: 1.964  (1.678)
#     ConDo GP-ReverseKL rMSE: 2.522  (1.974)
#     ConDo PoGMM-ReverseKL rMSE: 9.020  (6.802)
#     ConDo MMD rMSE: 14.542  (11.328)
# rix:3 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.283  (23.443)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.734  (11.731)
#     MMD rMSE: 8.979  (6.429)
#     ConDo Linear-ReverseKL rMSE: 6.896  (4.862)
#     ConDo GP-ReverseKL rMSE: 2.062  (1.560)
#     ConDo PoGMM-ReverseKL rMSE: 10.020  (6.986)
#     ConDo MMD rMSE: 162.340  (134.297)
# rix:3 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 17.752  (14.845)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 3.938  (3.414)
#     MMD rMSE: 12.823  (10.966)
#     ConDo Linear-ReverseKL rMSE: 8.099  (6.627)
#     ConDo GP-ReverseKL rMSE: 8.934  (7.467)
#     ConDo PoGMM-ReverseKL rMSE: 8.078  (6.676)
#     ConDo MMD rMSE: 5.320  (4.485)
# rix:3 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.522  (23.194)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.236  (17.494)
#     MMD rMSE: 6.220  (4.409)
#     ConDo Linear-ReverseKL rMSE: 3.302  (2.506)
#     ConDo GP-ReverseKL rMSE: 2.871  (2.092)
#     ConDo PoGMM-ReverseKL rMSE: 9.175  (6.540)
#     ConDo MMD rMSE: 208.549  (157.110)
# rix:3 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 30.982  (24.393)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.747  (10.239)
#     MMD rMSE: 6.564  (4.971)
#     ConDo Linear-ReverseKL rMSE: 4.872  (3.814)
#     ConDo GP-ReverseKL rMSE: 1.994  (1.863)
#     ConDo PoGMM-ReverseKL rMSE: 9.108  (6.798)
#     ConDo MMD rMSE: 8889.483  (6449.676)
# rix:3 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.044  (13.861)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.666  (4.027)
#     MMD rMSE: 14.463  (10.786)
#     ConDo Linear-ReverseKL rMSE: 7.361  (5.499)
#     ConDo GP-ReverseKL rMSE: 12.639  (9.291)
#     ConDo PoGMM-ReverseKL rMSE: 9.400  (6.931)
#     ConDo MMD rMSE: 1097.435  (752.378)
# rix:4 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.534  (23.611)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.423  (17.794)
#     MMD rMSE: 8.177  (6.056)
#     ConDo Linear-ReverseKL rMSE: 0.501  (1.121)
#     ConDo GP-ReverseKL rMSE: 0.550  (1.113)
#     ConDo PoGMM-ReverseKL rMSE: 0.916  (1.115)
#     ConDo MMD rMSE: 2.927  (2.067)
# rix:4 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.818  (24.638)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.792  (10.733)
#     MMD rMSE: 9.582  (7.190)
#     ConDo Linear-ReverseKL rMSE: 1.376  (1.443)
#     ConDo GP-ReverseKL rMSE: 1.422  (1.660)
#     ConDo PoGMM-ReverseKL rMSE: 1.630  (1.534)
#     ConDo MMD rMSE: 4.617  (3.366)
# rix:4 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.097  (13.463)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.582  (3.795)
#     MMD rMSE: 8.915  (6.475)
#     ConDo Linear-ReverseKL rMSE: 3.234  (2.738)
#     ConDo GP-ReverseKL rMSE: 2.297  (2.190)
#     ConDo PoGMM-ReverseKL rMSE: 2.345  (2.226)
#     ConDo MMD rMSE: 4.486  (3.174)
# rix:4 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.553  (23.995)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.638  (16.972)
#     MMD rMSE: 7.245  (5.351)
#     ConDo Linear-ReverseKL rMSE: 0.570  (1.051)
#     ConDo GP-ReverseKL rMSE: 0.584  (1.058)
#     ConDo PoGMM-ReverseKL rMSE: 4.767  (3.436)
#     ConDo MMD rMSE: 5.616  (4.168)
# rix:4 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.134  (24.383)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.336  (10.566)
#     MMD rMSE: 7.096  (5.220)
#     ConDo Linear-ReverseKL rMSE: 1.326  (1.350)
#     ConDo GP-ReverseKL rMSE: 1.767  (1.617)
#     ConDo PoGMM-ReverseKL rMSE: 5.736  (4.147)
#     ConDo MMD rMSE: 6.948  (5.079)
# rix:4 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.561  (13.721)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.193  (4.332)
#     MMD rMSE: 15.232  (11.234)
#     ConDo Linear-ReverseKL rMSE: 5.891  (4.326)
#     ConDo GP-ReverseKL rMSE: 2.966  (2.453)
#     ConDo PoGMM-ReverseKL rMSE: 5.698  (4.229)
#     ConDo MMD rMSE: 7.816  (5.547)
# rix:4 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.348  (23.099)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.302  (18.251)
#     MMD rMSE: 8.586  (6.189)
#     ConDo Linear-ReverseKL rMSE: 0.607  (1.143)
#     ConDo GP-ReverseKL rMSE: 0.672  (1.162)
#     ConDo PoGMM-ReverseKL rMSE: 5.976  (4.195)
#     ConDo MMD rMSE: 7.678  (5.576)
# rix:4 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 30.426  (24.249)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.261  (9.743)
#     MMD rMSE: 7.556  (5.655)
#     ConDo Linear-ReverseKL rMSE: 1.245  (1.413)
#     ConDo GP-ReverseKL rMSE: 1.578  (1.661)
#     ConDo PoGMM-ReverseKL rMSE: 5.635  (4.189)
#     ConDo MMD rMSE: 7.269  (5.553)
# rix:4 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 19.174  (15.058)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.961  (4.069)
#     MMD rMSE: 16.684  (12.888)
#     ConDo Linear-ReverseKL rMSE: 7.177  (5.377)
#     ConDo GP-ReverseKL rMSE: 7.293  (5.417)
#     ConDo PoGMM-ReverseKL rMSE: 6.979  (5.280)
#     ConDo MMD rMSE: 7.077  (5.410)
# rix:4 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.502  (22.845)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.580  (19.103)
#     MMD rMSE: 7.098  (4.973)
#     ConDo Linear-ReverseKL rMSE: 1.402  (1.363)
#     ConDo GP-ReverseKL rMSE: 1.282  (1.277)
#     ConDo PoGMM-ReverseKL rMSE: 7.932  (5.524)
#     ConDo MMD rMSE: 12.810  (9.302)
# rix:4 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.117  (25.690)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.499  (11.296)
#     MMD rMSE: 7.475  (5.972)
#     ConDo Linear-ReverseKL rMSE: 2.377  (2.056)
#     ConDo GP-ReverseKL rMSE: 1.682  (1.628)
#     ConDo PoGMM-ReverseKL rMSE: 8.512  (6.797)
#     ConDo MMD rMSE: 12.392  (10.050)
# rix:4 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.893  (14.407)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.826  (4.655)
#     MMD rMSE: 16.684  (12.905)
#     ConDo Linear-ReverseKL rMSE: 9.524  (6.975)
#     ConDo GP-ReverseKL rMSE: 8.711  (6.400)
#     ConDo PoGMM-ReverseKL rMSE: 9.265  (6.797)
#     ConDo MMD rMSE: 4.667  (3.214)
# rix:4 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.743  (24.334)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.545  (16.945)
#     MMD rMSE: 6.674  (4.991)
#     ConDo Linear-ReverseKL rMSE: 2.070  (1.730)
#     ConDo GP-ReverseKL rMSE: 2.503  (1.959)
#     ConDo PoGMM-ReverseKL rMSE: 9.173  (6.906)
#     ConDo MMD rMSE: 14.959  (11.608)
# rix:4 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.288  (23.312)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.670  (11.462)
#     MMD rMSE: 8.308  (5.885)
#     ConDo Linear-ReverseKL rMSE: 5.891  (4.143)
#     ConDo GP-ReverseKL rMSE: 1.887  (1.465)
#     ConDo PoGMM-ReverseKL rMSE: 9.784  (6.748)
#     ConDo MMD rMSE: 132.328  (109.184)
# rix:4 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 18.423  (15.109)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.382  (3.779)
#     MMD rMSE: 11.985  (10.077)
#     ConDo Linear-ReverseKL rMSE: 8.820  (7.079)
#     ConDo GP-ReverseKL rMSE: 10.001  (8.135)
#     ConDo PoGMM-ReverseKL rMSE: 8.637  (6.995)
#     ConDo MMD rMSE: 5.535  (4.560)
# rix:4 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.554  (23.162)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.105  (17.536)
#     MMD rMSE: 5.744  (4.055)
#     ConDo Linear-ReverseKL rMSE: 3.180  (2.385)
#     ConDo GP-ReverseKL rMSE: 2.863  (2.071)
#     ConDo PoGMM-ReverseKL rMSE: 8.839  (6.274)
#     ConDo MMD rMSE: 172.975  (130.295)
# rix:4 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 31.071  (24.626)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.882  (10.324)
#     MMD rMSE: 7.633  (5.861)
#     ConDo Linear-ReverseKL rMSE: 6.457  (5.054)
#     ConDo GP-ReverseKL rMSE: 2.313  (2.041)
#     ConDo PoGMM-ReverseKL rMSE: 9.284  (6.993)
#     ConDo MMD rMSE: 7114.660  (5162.196)
# rix:4 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.523  (13.831)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.898  (4.121)
#     MMD rMSE: 15.658  (11.371)
#     ConDo Linear-ReverseKL rMSE: 8.100  (5.818)
#     ConDo GP-ReverseKL rMSE: 13.040  (9.310)
#     ConDo PoGMM-ReverseKL rMSE: 9.598  (6.881)
#     ConDo MMD rMSE: 880.019  (603.233)
# rix:5 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.422  (23.846)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.307  (17.616)
#     MMD rMSE: 8.037  (6.040)
#     ConDo Linear-ReverseKL rMSE: 0.489  (1.108)
#     ConDo GP-ReverseKL rMSE: 0.534  (1.105)
#     ConDo PoGMM-ReverseKL rMSE: 0.905  (1.105)
#     ConDo MMD rMSE: 2.782  (1.999)
# rix:5 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 32.057  (24.656)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.129  (11.245)
#     MMD rMSE: 11.073  (8.218)
#     ConDo Linear-ReverseKL rMSE: 1.551  (1.475)
#     ConDo GP-ReverseKL rMSE: 1.375  (1.569)
#     ConDo PoGMM-ReverseKL rMSE: 1.682  (1.509)
#     ConDo MMD rMSE: 4.747  (3.414)
# rix:5 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.183  (13.090)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.610  (3.751)
#     MMD rMSE: 8.761  (6.116)
#     ConDo Linear-ReverseKL rMSE: 3.159  (2.608)
#     ConDo GP-ReverseKL rMSE: 2.190  (2.151)
#     ConDo PoGMM-ReverseKL rMSE: 2.230  (2.179)
#     ConDo MMD rMSE: 4.456  (3.022)
# rix:5 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.376  (24.053)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.557  (17.023)
#     MMD rMSE: 6.387  (4.731)
#     ConDo Linear-ReverseKL rMSE: 0.578  (1.039)
#     ConDo GP-ReverseKL rMSE: 0.599  (1.046)
#     ConDo PoGMM-ReverseKL rMSE: 4.609  (3.357)
#     ConDo MMD rMSE: 5.558  (4.168)
# rix:5 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.063  (24.504)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.278  (10.758)
#     MMD rMSE: 6.669  (4.940)
#     ConDo Linear-ReverseKL rMSE: 1.317  (1.339)
#     ConDo GP-ReverseKL rMSE: 1.592  (1.554)
#     ConDo PoGMM-ReverseKL rMSE: 5.501  (4.018)
#     ConDo MMD rMSE: 6.676  (4.929)
# rix:5 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 18.824  (13.788)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.226  (4.277)
#     MMD rMSE: 16.049  (11.715)
#     ConDo Linear-ReverseKL rMSE: 6.116  (4.389)
#     ConDo GP-ReverseKL rMSE: 2.937  (2.403)
#     ConDo PoGMM-ReverseKL rMSE: 5.797  (4.208)
#     ConDo MMD rMSE: 7.931  (5.549)
# rix:5 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.310  (22.926)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.263  (18.328)
#     MMD rMSE: 7.533  (5.407)
#     ConDo Linear-ReverseKL rMSE: 0.580  (1.157)
#     ConDo GP-ReverseKL rMSE: 0.635  (1.177)
#     ConDo PoGMM-ReverseKL rMSE: 5.899  (4.103)
#     ConDo MMD rMSE: 7.446  (5.367)
# rix:5 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 30.679  (24.365)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.491  (9.968)
#     MMD rMSE: 7.456  (5.583)
#     ConDo Linear-ReverseKL rMSE: 1.451  (1.501)
#     ConDo GP-ReverseKL rMSE: 1.792  (1.749)
#     ConDo PoGMM-ReverseKL rMSE: 5.938  (4.411)
#     ConDo MMD rMSE: 7.640  (5.826)
# rix:5 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 18.970  (14.627)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.746  (3.919)
#     MMD rMSE: 16.895  (12.818)
#     ConDo Linear-ReverseKL rMSE: 6.651  (4.926)
#     ConDo GP-ReverseKL rMSE: 7.150  (5.192)
#     ConDo PoGMM-ReverseKL rMSE: 6.718  (4.975)
#     ConDo MMD rMSE: 7.014  (5.217)
# rix:5 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.510  (23.320)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.579  (18.804)
#     MMD rMSE: 6.789  (4.853)
#     ConDo Linear-ReverseKL rMSE: 1.480  (1.407)
#     ConDo GP-ReverseKL rMSE: 1.293  (1.280)
#     ConDo PoGMM-ReverseKL rMSE: 7.857  (5.614)
#     ConDo MMD rMSE: 12.435  (9.202)
# rix:5 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.249  (25.544)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.604  (11.417)
#     MMD rMSE: 6.917  (5.491)
#     ConDo Linear-ReverseKL rMSE: 2.581  (2.144)
#     ConDo GP-ReverseKL rMSE: 1.930  (1.737)
#     ConDo PoGMM-ReverseKL rMSE: 8.706  (6.845)
#     ConDo MMD rMSE: 12.843  (10.278)
# rix:5 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.825  (13.671)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.558  (4.439)
#     MMD rMSE: 16.984  (12.420)
#     ConDo Linear-ReverseKL rMSE: 9.272  (6.380)
#     ConDo GP-ReverseKL rMSE: 8.202  (5.745)
#     ConDo PoGMM-ReverseKL rMSE: 9.015  (6.214)
#     ConDo MMD rMSE: 5.160  (3.223)
# rix:5 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.687  (24.213)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.525  (17.369)
#     MMD rMSE: 6.575  (4.910)
#     ConDo Linear-ReverseKL rMSE: 2.040  (1.712)
#     ConDo GP-ReverseKL rMSE: 2.315  (1.862)
#     ConDo PoGMM-ReverseKL rMSE: 9.046  (6.793)
#     ConDo MMD rMSE: 14.388  (11.122)
# rix:5 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.277  (23.561)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.811  (11.456)
#     MMD rMSE: 9.086  (6.578)
#     ConDo Linear-ReverseKL rMSE: 6.520  (4.680)
#     ConDo GP-ReverseKL rMSE: 1.752  (1.434)
#     ConDo PoGMM-ReverseKL rMSE: 10.039  (7.063)
#     ConDo MMD rMSE: 112.825  (92.986)
# rix:5 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 18.394  (15.214)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.482  (3.888)
#     MMD rMSE: 11.759  (9.906)
#     ConDo Linear-ReverseKL rMSE: 8.849  (7.180)
#     ConDo GP-ReverseKL rMSE: 9.980  (8.184)
#     ConDo PoGMM-ReverseKL rMSE: 8.689  (7.103)
#     ConDo MMD rMSE: 5.710  (4.736)
# rix:5 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.649  (23.428)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.254  (17.595)
#     MMD rMSE: 6.238  (4.492)
#     ConDo Linear-ReverseKL rMSE: 2.919  (2.234)
#     ConDo GP-ReverseKL rMSE: 2.849  (2.092)
#     ConDo PoGMM-ReverseKL rMSE: 9.064  (6.528)
#     ConDo MMD rMSE: 173.695  (131.748)
# rix:5 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 30.921  (24.585)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.802  (10.336)
#     MMD rMSE: 7.620  (5.852)
#     ConDo Linear-ReverseKL rMSE: 7.027  (5.479)
#     ConDo GP-ReverseKL rMSE: 2.040  (1.901)
#     ConDo PoGMM-ReverseKL rMSE: 9.103  (6.875)
#     ConDo MMD rMSE: 6361.793  (4646.755)
# rix:5 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.178  (13.672)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.566  (3.916)
#     MMD rMSE: 14.641  (10.667)
#     ConDo Linear-ReverseKL rMSE: 7.471  (5.400)
#     ConDo GP-ReverseKL rMSE: 12.745  (9.159)
#     ConDo PoGMM-ReverseKL rMSE: 9.331  (6.727)
#     ConDo MMD rMSE: 818.047  (567.184)
# rix:6 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.498  (24.052)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.422  (17.689)
#     MMD rMSE: 9.047  (6.907)
#     ConDo Linear-ReverseKL rMSE: 0.512  (1.106)
#     ConDo GP-ReverseKL rMSE: 0.559  (1.105)
#     ConDo PoGMM-ReverseKL rMSE: 0.924  (1.118)
#     ConDo MMD rMSE: 2.870  (2.093)
# rix:6 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.953  (24.571)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.948  (11.040)
#     MMD rMSE: 10.373  (7.682)
#     ConDo Linear-ReverseKL rMSE: 1.523  (1.449)
#     ConDo GP-ReverseKL rMSE: 1.296  (1.520)
#     ConDo PoGMM-ReverseKL rMSE: 1.659  (1.486)
#     ConDo MMD rMSE: 4.636  (3.330)
# rix:6 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.234  (13.066)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.737  (3.786)
#     MMD rMSE: 10.158  (7.088)
#     ConDo Linear-ReverseKL rMSE: 3.229  (2.613)
#     ConDo GP-ReverseKL rMSE: 2.180  (2.127)
#     ConDo PoGMM-ReverseKL rMSE: 2.225  (2.155)
#     ConDo MMD rMSE: 4.743  (3.196)
# rix:6 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.419  (24.076)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.309  (16.823)
#     MMD rMSE: 5.906  (4.377)
#     ConDo Linear-ReverseKL rMSE: 0.564  (1.053)
#     ConDo GP-ReverseKL rMSE: 0.580  (1.060)
#     ConDo PoGMM-ReverseKL rMSE: 4.371  (3.198)
#     ConDo MMD rMSE: 5.235  (3.924)
# rix:6 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.119  (24.473)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.025  (10.270)
#     MMD rMSE: 7.211  (5.333)
#     ConDo Linear-ReverseKL rMSE: 1.309  (1.320)
#     ConDo GP-ReverseKL rMSE: 1.628  (1.537)
#     ConDo PoGMM-ReverseKL rMSE: 5.320  (3.867)
#     ConDo MMD rMSE: 6.353  (4.670)
# rix:6 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 19.236  (13.953)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.643  (4.513)
#     MMD rMSE: 16.858  (12.177)
#     ConDo Linear-ReverseKL rMSE: 6.448  (4.527)
#     ConDo GP-ReverseKL rMSE: 3.115  (2.456)
#     ConDo PoGMM-ReverseKL rMSE: 6.346  (4.481)
#     ConDo MMD rMSE: 9.900  (6.891)
# rix:6 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.298  (23.327)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.158  (17.664)
#     MMD rMSE: 7.218  (5.266)
#     ConDo Linear-ReverseKL rMSE: 0.580  (1.140)
#     ConDo GP-ReverseKL rMSE: 0.626  (1.157)
#     ConDo PoGMM-ReverseKL rMSE: 5.856  (4.177)
#     ConDo MMD rMSE: 7.352  (5.409)
# rix:6 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 30.886  (24.411)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.762  (10.186)
#     MMD rMSE: 7.485  (5.587)
#     ConDo Linear-ReverseKL rMSE: 1.642  (1.584)
#     ConDo GP-ReverseKL rMSE: 1.729  (1.689)
#     ConDo PoGMM-ReverseKL rMSE: 6.292  (4.654)
#     ConDo MMD rMSE: 7.943  (6.027)
# rix:6 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 18.645  (14.445)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.452  (3.673)
#     MMD rMSE: 16.866  (12.895)
#     ConDo Linear-ReverseKL rMSE: 6.565  (4.886)
#     ConDo GP-ReverseKL rMSE: 7.052  (5.158)
#     ConDo PoGMM-ReverseKL rMSE: 6.461  (4.809)
#     ConDo MMD rMSE: 6.605  (4.925)
# rix:6 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.458  (23.411)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.512  (18.587)
#     MMD rMSE: 7.206  (5.223)
#     ConDo Linear-ReverseKL rMSE: 1.472  (1.399)
#     ConDo GP-ReverseKL rMSE: 1.266  (1.272)
#     ConDo PoGMM-ReverseKL rMSE: 7.802  (5.619)
#     ConDo MMD rMSE: 12.380  (9.226)
# rix:6 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.091  (25.228)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.446  (11.355)
#     MMD rMSE: 6.459  (5.086)
#     ConDo Linear-ReverseKL rMSE: 2.325  (2.005)
#     ConDo GP-ReverseKL rMSE: 2.030  (1.765)
#     ConDo PoGMM-ReverseKL rMSE: 8.526  (6.636)
#     ConDo MMD rMSE: 12.782  (10.140)
# rix:6 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.922  (13.539)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.660  (4.500)
#     MMD rMSE: 17.345  (12.467)
#     ConDo Linear-ReverseKL rMSE: 9.258  (6.248)
#     ConDo GP-ReverseKL rMSE: 7.747  (5.364)
#     ConDo PoGMM-ReverseKL rMSE: 9.164  (6.182)
#     ConDo MMD rMSE: 5.284  (3.276)
# rix:6 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.682  (24.163)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.512  (17.744)
#     MMD rMSE: 6.848  (5.108)
#     ConDo Linear-ReverseKL rMSE: 2.072  (1.714)
#     ConDo GP-ReverseKL rMSE: 2.239  (1.803)
#     ConDo PoGMM-ReverseKL rMSE: 8.944  (6.696)
#     ConDo MMD rMSE: 14.349  (11.045)
# rix:6 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.283  (23.835)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.682  (11.156)
#     MMD rMSE: 8.724  (6.370)
#     ConDo Linear-ReverseKL rMSE: 6.741  (4.912)
#     ConDo GP-ReverseKL rMSE: 1.717  (1.434)
#     ConDo PoGMM-ReverseKL rMSE: 9.917  (7.082)
#     ConDo MMD rMSE: 103.143  (84.856)
# rix:6 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 18.452  (14.686)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.476  (3.839)
#     MMD rMSE: 11.572  (9.315)
#     ConDo Linear-ReverseKL rMSE: 8.878  (6.832)
#     ConDo GP-ReverseKL rMSE: 10.051  (7.803)
#     ConDo PoGMM-ReverseKL rMSE: 8.793  (6.795)
#     ConDo MMD rMSE: 5.590  (4.430)
# rix:6 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.511  (23.511)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.059  (16.929)
#     MMD rMSE: 6.314  (4.609)
#     ConDo Linear-ReverseKL rMSE: 2.609  (2.083)
#     ConDo GP-ReverseKL rMSE: 2.651  (1.998)
#     ConDo PoGMM-ReverseKL rMSE: 8.882  (6.462)
#     ConDo MMD rMSE: 4227.673  (3373.211)
# rix:6 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 30.871  (24.346)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.796  (10.576)
#     MMD rMSE: 6.892  (5.273)
#     ConDo Linear-ReverseKL rMSE: 6.651  (5.140)
#     ConDo GP-ReverseKL rMSE: 2.106  (1.900)
#     ConDo PoGMM-ReverseKL rMSE: 9.034  (6.762)
#     ConDo MMD rMSE: 5534.328  (4042.784)
# rix:6 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.431  (13.778)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.925  (4.151)
#     MMD rMSE: 13.472  (9.786)
#     ConDo Linear-ReverseKL rMSE: 7.823  (5.620)
#     ConDo GP-ReverseKL rMSE: 13.127  (9.384)
#     ConDo PoGMM-ReverseKL rMSE: 9.669  (6.930)
#     ConDo MMD rMSE: 770.195  (534.856)
# rix:7 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.479  (24.087)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.402  (17.327)
#     MMD rMSE: 8.604  (6.564)
#     ConDo Linear-ReverseKL rMSE: 0.516  (1.097)
#     ConDo GP-ReverseKL rMSE: 0.570  (1.094)
#     ConDo PoGMM-ReverseKL rMSE: 0.982  (1.131)
#     ConDo MMD rMSE: 2.887  (2.111)
# ...
#     ConDo PoGMM-ReverseKL rMSE: 8.789  (5.909)
#     ConDo MMD rMSE: 5.556  (3.473)
# rix:7 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.658  (24.180)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.327  (17.348)
#     MMD rMSE: 6.310  (4.703)
#     ConDo Linear-ReverseKL rMSE: 1.935  (1.632)
#     ConDo GP-ReverseKL rMSE: 2.173  (1.750)
#     ConDo PoGMM-ReverseKL rMSE: 8.730  (6.534)
#     ConDo MMD rMSE: 14.264  (10.990)
# rix:7 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.228  (24.038)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.788  (11.283)
#     MMD rMSE: 8.859  (6.558)
#     ConDo Linear-ReverseKL rMSE: 6.342  (4.654)
#     ConDo GP-ReverseKL rMSE: 2.213  (1.819)
#     ConDo PoGMM-ReverseKL rMSE: 10.048  (7.292)
#     ConDo MMD rMSE: 92.671  (76.211)
# rix:7 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 18.418  (14.451)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.487  (3.812)
#     MMD rMSE: 10.930  (8.684)
#     ConDo Linear-ReverseKL rMSE: 8.899  (6.727)
#     ConDo GP-ReverseKL rMSE: 10.077  (7.677)
#     ConDo PoGMM-ReverseKL rMSE: 8.824  (6.694)
#     ConDo MMD rMSE: 5.556  (4.316)
# rix:7 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.500  (23.605)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.062  (17.206)
#     MMD rMSE: 5.964  (4.369)
#     ConDo Linear-ReverseKL rMSE: 2.519  (2.029)
#     ConDo GP-ReverseKL rMSE: 2.655  (2.017)
#     ConDo PoGMM-ReverseKL rMSE: 8.853  (6.483)
#     ConDo MMD rMSE: 3701.214  (2953.120)
# rix:7 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 30.593  (24.294)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.553  (10.372)
#     MMD rMSE: 6.879  (5.301)
#     ConDo Linear-ReverseKL rMSE: 6.135  (4.758)
#     ConDo GP-ReverseKL rMSE: 2.087  (1.923)
#     ConDo PoGMM-ReverseKL rMSE: 8.678  (6.537)
#     ConDo MMD rMSE: 5017.736  (3682.129)
# rix:7 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.465  (13.750)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.070  (4.252)
#     MMD rMSE: 13.025  (9.441)
#     ConDo Linear-ReverseKL rMSE: 7.748  (5.575)
#     ConDo GP-ReverseKL rMSE: 13.142  (9.390)
#     ConDo PoGMM-ReverseKL rMSE: 9.815  (7.032)
#     ConDo MMD rMSE: 1005.698  (704.195)
# rix:8 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.503  (24.020)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.423  (17.594)
#     MMD rMSE: 8.348  (6.336)
#     ConDo Linear-ReverseKL rMSE: 0.534  (1.099)
#     ConDo GP-ReverseKL rMSE: 0.582  (1.096)
#     ConDo PoGMM-ReverseKL rMSE: 1.015  (1.143)
#     ConDo MMD rMSE: 2.936  (2.140)
# rix:8 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.927  (24.547)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.027  (11.343)
#     MMD rMSE: 10.865  (8.034)
#     ConDo Linear-ReverseKL rMSE: 1.507  (1.432)
#     ConDo GP-ReverseKL rMSE: 1.195  (1.499)
#     ConDo PoGMM-ReverseKL rMSE: 1.612  (1.462)
#     ConDo MMD rMSE: 4.634  (3.334)
# rix:8 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.119  (12.916)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.555  (3.674)
#     MMD rMSE: 10.506  (7.374)
#     ConDo Linear-ReverseKL rMSE: 3.044  (2.505)
#     ConDo GP-ReverseKL rMSE: 2.081  (2.076)
#     ConDo PoGMM-ReverseKL rMSE: 2.120  (2.094)
#     ConDo MMD rMSE: 4.512  (3.028)
# rix:8 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.420  (24.071)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.172  (16.901)
#     MMD rMSE: 6.289  (4.688)
#     ConDo Linear-ReverseKL rMSE: 0.538  (1.069)
#     ConDo GP-ReverseKL rMSE: 0.551  (1.078)
#     ConDo PoGMM-ReverseKL rMSE: 4.236  (3.101)
#     ConDo MMD rMSE: 4.941  (3.699)
# rix:8 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.234  (24.485)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.314  (10.624)
#     MMD rMSE: 7.988  (5.928)
#     ConDo Linear-ReverseKL rMSE: 1.276  (1.314)
#     ConDo GP-ReverseKL rMSE: 1.676  (1.580)
#     ConDo PoGMM-ReverseKL rMSE: 5.632  (4.102)
#     ConDo MMD rMSE: 6.665  (4.914)
# rix:8 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 19.328  (14.108)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.406  (4.420)
#     MMD rMSE: 17.478  (12.726)
#     ConDo Linear-ReverseKL rMSE: 6.251  (4.415)
#     ConDo GP-ReverseKL rMSE: 2.915  (2.373)
#     ConDo PoGMM-ReverseKL rMSE: 6.116  (4.339)
#     ConDo MMD rMSE: 9.078  (6.337)
# rix:8 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.266  (23.357)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.330  (17.902)
#     MMD rMSE: 6.839  (4.995)
#     ConDo Linear-ReverseKL rMSE: 0.626  (1.131)
#     ConDo GP-ReverseKL rMSE: 0.661  (1.147)
#     ConDo PoGMM-ReverseKL rMSE: 6.084  (4.357)
#     ConDo MMD rMSE: 8.020  (5.938)
# rix:8 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 31.017  (24.380)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.215  (10.835)
#     MMD rMSE: 7.648  (5.688)
#     ConDo Linear-ReverseKL rMSE: 1.677  (1.568)
#     ConDo GP-ReverseKL rMSE: 2.086  (1.871)
#     ConDo PoGMM-ReverseKL rMSE: 6.651  (4.888)
#     ConDo MMD rMSE: 8.704  (6.579)
# rix:8 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 18.558  (14.156)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.420  (3.678)
#     MMD rMSE: 17.175  (12.950)
#     ConDo Linear-ReverseKL rMSE: 6.448  (4.711)
#     ConDo GP-ReverseKL rMSE: 6.866  (4.929)
#     ConDo PoGMM-ReverseKL rMSE: 6.390  (4.665)
#     ConDo MMD rMSE: 6.588  (4.818)
# rix:8 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.493  (23.450)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.414  (18.125)
#     MMD rMSE: 7.602  (5.540)
#     ConDo Linear-ReverseKL rMSE: 1.364  (1.352)
#     ConDo GP-ReverseKL rMSE: 1.256  (1.254)
#     ConDo PoGMM-ReverseKL rMSE: 7.724  (5.562)
#     ConDo MMD rMSE: 11.951  (8.908)
# rix:8 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.149  (24.748)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.415  (11.420)
#     MMD rMSE: 7.591  (5.755)
#     ConDo Linear-ReverseKL rMSE: 2.141  (1.861)
#     ConDo GP-ReverseKL rMSE: 2.019  (1.712)
#     ConDo PoGMM-ReverseKL rMSE: 8.491  (6.427)
#     ConDo MMD rMSE: 12.581  (9.766)
# rix:8 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 18.966  (13.479)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.375  (4.341)
#     MMD rMSE: 17.739  (12.644)
#     ConDo Linear-ReverseKL rMSE: 8.987  (5.980)
#     ConDo GP-ReverseKL rMSE: 7.659  (5.198)
#     ConDo PoGMM-ReverseKL rMSE: 8.751  (5.826)
#     ConDo MMD rMSE: 5.171  (3.235)
# rix:8 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.582  (24.146)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.299  (17.526)
#     MMD rMSE: 5.992  (4.465)
#     ConDo Linear-ReverseKL rMSE: 1.894  (1.600)
#     ConDo GP-ReverseKL rMSE: 2.298  (1.829)
#     ConDo PoGMM-ReverseKL rMSE: 8.635  (6.465)
#     ConDo MMD rMSE: 14.194  (10.940)
# rix:8 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.276  (24.239)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.843  (11.285)
#     MMD rMSE: 9.360  (7.018)
#     ConDo Linear-ReverseKL rMSE: 5.769  (4.288)
#     ConDo GP-ReverseKL rMSE: 2.109  (1.772)
#     ConDo PoGMM-ReverseKL rMSE: 10.122  (7.426)
#     ConDo MMD rMSE: 84.114  (69.145)
# rix:8 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 18.512  (14.433)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.389  (3.756)
#     MMD rMSE: 11.856  (9.307)
#     ConDo Linear-ReverseKL rMSE: 9.019  (6.752)
#     ConDo GP-ReverseKL rMSE: 10.185  (7.681)
#     ConDo PoGMM-ReverseKL rMSE: 8.778  (6.600)
#     ConDo MMD rMSE: 5.502  (4.230)
# rix:8 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.452  (23.619)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.977  (16.968)
#     MMD rMSE: 5.848  (4.292)
#     ConDo Linear-ReverseKL rMSE: 2.435  (1.965)
#     ConDo GP-ReverseKL rMSE: 2.543  (1.948)
#     ConDo PoGMM-ReverseKL rMSE: 8.722  (6.397)
#     ConDo MMD rMSE: 3293.978  (2628.145)
# rix:8 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 30.615  (24.389)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.554  (10.566)
#     MMD rMSE: 7.404  (5.742)
#     ConDo Linear-ReverseKL rMSE: 5.571  (4.368)
#     ConDo GP-ReverseKL rMSE: 2.000  (1.859)
#     ConDo PoGMM-ReverseKL rMSE: 8.521  (6.444)
#     ConDo MMD rMSE: 4870.032  (3603.964)
# rix:8 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.518  (13.351)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.044  (4.221)
#     MMD rMSE: 12.693  (8.903)
#     ConDo Linear-ReverseKL rMSE: 7.884  (5.396)
#     ConDo GP-ReverseKL rMSE: 13.071  (8.966)
#     ConDo PoGMM-ReverseKL rMSE: 9.774  (6.715)
#     ConDo MMD rMSE: 894.162  (626.102)
# rix:9 NoiseFree-TargetShift-FeatureShift-1 Homoscedastic Linear
#     batch-effected rMSE: 30.421  (24.084)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.269  (17.166)
#     MMD rMSE: 8.294  (6.330)
#     ConDo Linear-ReverseKL rMSE: 0.531  (1.096)
#     ConDo GP-ReverseKL rMSE: 0.572  (1.090)
#     ConDo PoGMM-ReverseKL rMSE: 0.979  (1.128)
#     ConDo MMD rMSE: 2.828  (2.073)
# rix:9 NoiseFree-TargetShift-FeatureShift-1 Heteroscedastic Linear
#     batch-effected rMSE: 31.923  (24.490)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.944  (11.300)
#     MMD rMSE: 10.621  (7.832)
#     ConDo Linear-ReverseKL rMSE: 1.430  (1.411)
#     ConDo GP-ReverseKL rMSE: 1.236  (1.538)
#     ConDo PoGMM-ReverseKL rMSE: 1.525  (1.440)
#     ConDo MMD rMSE: 4.552  (3.260)
# rix:9 NoiseFree-TargetShift-FeatureShift-1 Nonlinear
#     batch-effected rMSE: 18.088  (13.100)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.573  (3.720)
#     MMD rMSE: 11.236  (8.113)
#     ConDo Linear-ReverseKL rMSE: 3.037  (2.523)
#     ConDo GP-ReverseKL rMSE: 2.074  (2.075)
#     ConDo PoGMM-ReverseKL rMSE: 2.083  (2.077)
#     ConDo MMD rMSE: 4.675  (3.228)
# rix:9 NoiseFree-TargetShift-FeatureShift-2 Homoscedastic Linear
#     batch-effected rMSE: 30.376  (24.029)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.180  (17.164)
#     MMD rMSE: 6.273  (4.681)
#     ConDo Linear-ReverseKL rMSE: 0.535  (1.078)
#     ConDo GP-ReverseKL rMSE: 0.556  (1.086)
#     ConDo PoGMM-ReverseKL rMSE: 4.235  (3.110)
#     ConDo MMD rMSE: 5.018  (3.762)
# rix:9 NoiseFree-TargetShift-FeatureShift-2 Heteroscedastic Linear
#     batch-effected rMSE: 31.253  (24.592)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.272  (10.553)
#     MMD rMSE: 7.793  (5.808)
#     ConDo Linear-ReverseKL rMSE: 1.282  (1.314)
#     ConDo GP-ReverseKL rMSE: 1.756  (1.621)
#     ConDo PoGMM-ReverseKL rMSE: 5.539  (4.056)
#     ConDo MMD rMSE: 6.557  (4.859)
# rix:9 NoiseFree-TargetShift-FeatureShift-2 Nonlinear
#     batch-effected rMSE: 19.275  (14.064)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.182  (4.209)
#     MMD rMSE: 17.610  (12.820)
#     ConDo Linear-ReverseKL rMSE: 6.132  (4.317)
#     ConDo GP-ReverseKL rMSE: 2.953  (2.376)
#     ConDo PoGMM-ReverseKL rMSE: 5.868  (4.164)
#     ConDo MMD rMSE: 8.641  (6.021)
# rix:9 NoiseFree-TargetShift-FeatureShift-4 Homoscedastic Linear
#     batch-effected rMSE: 30.305  (23.362)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.388  (17.991)
#     MMD rMSE: 6.514  (4.745)
#     ConDo Linear-ReverseKL rMSE: 0.615  (1.123)
#     ConDo GP-ReverseKL rMSE: 0.654  (1.136)
#     ConDo PoGMM-ReverseKL rMSE: 6.115  (4.368)
#     ConDo MMD rMSE: 8.013  (5.928)
# rix:9 NoiseFree-TargetShift-FeatureShift-4 Heteroscedastic Linear
#     batch-effected rMSE: 31.152  (24.441)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.298  (10.790)
#     MMD rMSE: 8.568  (6.380)
#     ConDo Linear-ReverseKL rMSE: 1.850  (1.653)
#     ConDo GP-ReverseKL rMSE: 2.330  (2.004)
#     ConDo PoGMM-ReverseKL rMSE: 6.757  (4.953)
#     ConDo MMD rMSE: 9.001  (6.793)
# rix:9 NoiseFree-TargetShift-FeatureShift-4 Nonlinear
#     batch-effected rMSE: 18.877  (14.142)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.658  (3.808)
#     MMD rMSE: 17.633  (13.057)
#     ConDo Linear-ReverseKL rMSE: 6.597  (4.696)
#     ConDo GP-ReverseKL rMSE: 6.825  (4.809)
#     ConDo PoGMM-ReverseKL rMSE: 6.588  (4.681)
#     ConDo MMD rMSE: 6.859  (4.881)
# rix:9 NoiseFree-TargetShift-FeatureShift-8 Homoscedastic Linear
#     batch-effected rMSE: 30.527  (23.518)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.475  (18.085)
#     MMD rMSE: 7.570  (5.533)
#     ConDo Linear-ReverseKL rMSE: 1.339  (1.339)
#     ConDo GP-ReverseKL rMSE: 1.224  (1.247)
#     ConDo PoGMM-ReverseKL rMSE: 7.847  (5.672)
#     ConDo MMD rMSE: 12.044  (9.004)
# rix:9 NoiseFree-TargetShift-FeatureShift-8 Heteroscedastic Linear
#     batch-effected rMSE: 31.031  (24.667)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.344  (11.405)
#     MMD rMSE: 7.796  (5.923)
#     ConDo Linear-ReverseKL rMSE: 2.217  (1.896)
#     ConDo GP-ReverseKL rMSE: 2.066  (1.735)
#     ConDo PoGMM-ReverseKL rMSE: 8.368  (6.334)
#     ConDo MMD rMSE: 12.842  (9.976)
# rix:9 NoiseFree-TargetShift-FeatureShift-8 Nonlinear
#     batch-effected rMSE: 19.228  (13.518)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 5.612  (4.455)
#     MMD rMSE: 16.920  (11.953)
#     ConDo Linear-ReverseKL rMSE: 9.181  (6.022)
#     ConDo GP-ReverseKL rMSE: 7.595  (5.091)
#     ConDo PoGMM-ReverseKL rMSE: 8.956  (5.877)
#     ConDo MMD rMSE: 5.565  (3.448)
# rix:9 NoiseFree-TargetShift-FeatureShift-16 Homoscedastic Linear
#     batch-effected rMSE: 30.567  (24.075)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.337  (17.943)
#     MMD rMSE: 6.272  (4.664)
#     ConDo Linear-ReverseKL rMSE: 2.015  (1.665)
#     ConDo GP-ReverseKL rMSE: 2.440  (1.914)
#     ConDo PoGMM-ReverseKL rMSE: 8.624  (6.437)
#     ConDo MMD rMSE: 14.505  (11.130)
# rix:9 NoiseFree-TargetShift-FeatureShift-16 Heteroscedastic Linear
#     batch-effected rMSE: 31.177  (24.091)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 8.845  (11.282)
#     MMD rMSE: 9.726  (7.256)
#     ConDo Linear-ReverseKL rMSE: 5.515  (4.082)
#     ConDo GP-ReverseKL rMSE: 2.401  (1.940)
#     ConDo PoGMM-ReverseKL rMSE: 10.139  (7.406)
#     ConDo MMD rMSE: 77.437  (63.497)
# rix:9 NoiseFree-TargetShift-FeatureShift-16 Nonlinear
#     batch-effected rMSE: 18.322  (14.385)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.407  (3.777)
#     MMD rMSE: 11.335  (8.921)
#     ConDo Linear-ReverseKL rMSE: 8.904  (6.723)
#     ConDo GP-ReverseKL rMSE: 9.972  (7.573)
#     ConDo PoGMM-ReverseKL rMSE: 8.683  (6.582)
#     ConDo MMD rMSE: 420.469  (347.454)
# rix:9 NoiseFree-TargetShift-FeatureShift-32 Homoscedastic Linear
#     batch-effected rMSE: 30.401  (23.695)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 9.020  (16.946)
#     MMD rMSE: 5.665  (4.173)
#     ConDo Linear-ReverseKL rMSE: 2.279  (1.879)
#     ConDo GP-ReverseKL rMSE: 2.495  (1.923)
#     ConDo PoGMM-ReverseKL rMSE: 8.817  (6.512)
#     ConDo MMD rMSE: 2979.175  (2377.039)
# rix:9 NoiseFree-TargetShift-FeatureShift-32 Heteroscedastic Linear
#     batch-effected rMSE: 30.755  (24.710)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 7.629  (10.586)
#     MMD rMSE: 7.869  (6.194)
#     ConDo Linear-ReverseKL rMSE: 5.271  (4.159)
#     ConDo GP-ReverseKL rMSE: 1.873  (1.793)
#     ConDo PoGMM-ReverseKL rMSE: 8.743  (6.711)
#     ConDo MMD rMSE: 4418.222  (3273.739)
# rix:9 NoiseFree-TargetShift-FeatureShift-32 Nonlinear
#     batch-effected rMSE: 18.323  (13.529)
#     Oracle rMSE: 0.000  (0.000)
#     Gaussian OT rMSE: 4.891  (4.127)
#     MMD rMSE: 13.080  (9.526)
#     ConDo Linear-ReverseKL rMSE: 7.867  (5.571)
#     ConDo GP-ReverseKL rMSE: 12.864  (9.082)
#     ConDo PoGMM-ReverseKL rMSE: 9.606  (6.792)
#     ConDo MMD rMSE: 1152.566  (880.981)

# %%
methods = [
    "true (unobserved)",
    "batch-effected",
    "Gaussian OT",
    "MMD",
    "ConDo Linear-ReverseKL", 
    "ConDo PoGMM-ReverseKL",
    "ConDo GP-ReverseKL",
    "ConDo MMD",
]
print_methods = [f"source - {meth}" for meth in methods]
num_multivars = len(multivar_settings)
multivars_np = np.array([int(mv) for mv in multivar_settings])
for prob_setting in prob_settings:
    fig = plt.figure(dpi=150, figsize=(3, 2))
    for _ in range(2):
        # skip target, source-true
        next(plt.gca()._get_lines.prop_cycler)

    # skip true (always 0)
    for method in methods[1:]:
        # generate np.array of size (num_multivars, num_random)
        plot_rmses = -1 * np.ones((num_multivars, num_random))
        for mvix, mv_setting in enumerate(multivar_settings):
            sstr = f"{noise_setting}-{targetshift_setting}-{featureshift_setting}-{mv_setting}"
            for rix in range(num_random):
                plot_rmses[mvix, :] = np.array(rMSEs[sstr][method][prob_setting])
        plt.errorbar(
            multivars_np,
            np.mean(plot_rmses, axis=1),
            yerr=np.minimum(25, np.std(plot_rmses, axis=1)), marker='x');
    plt.ylabel('rMSE');
    plt.xlabel('# confounders');
    plt.xscale('log');
    plt.xticks([int(mv) for mv in multivar_settings], multivar_settings);
    plt.legend(
        print_methods[1:],
        title='', loc="center left", bbox_to_anchor=(1.05, 0.5),
        frameon=False,
    );
    plt.gca().set_ylim(-1, 35);
    figname = f"figure-continuous1d-split-{prob_setting}-rmses-{num_random}.pdf"
    fig.savefig(figname, bbox_inches="tight")
for prob_setting in prob_settings:
    fig = plt.figure(dpi=150, figsize=(3, 2))
    for _ in range(2):
        # skip target, source-true
        next(plt.gca()._get_lines.prop_cycler)

    # skip true (always 0)
    for method in methods[1:]:
        # generate np.array of size (num_multivars, num_random)
        plot_rmses = -1 * np.ones((num_multivars, num_random))
        for mvix, mv_setting in enumerate(multivar_settings):
            sstr = f"{noise_setting}-{targetshift_setting}-{featureshift_setting}-{mv_setting}"
            for rix in range(num_random):
                plot_rmses[mvix, :] = np.array(rMSEs_test[sstr][method][prob_setting])
        plt.errorbar(
            multivars_np,
            np.mean(plot_rmses, axis=1),
            yerr=np.minimum(35, np.std(plot_rmses, axis=1)), marker='x');
    plt.ylabel('rMSE');
    plt.xlabel('# confounders');
    plt.xscale('log');
    plt.xticks([int(mv) for mv in multivar_settings], multivar_settings);
    plt.legend(
        print_methods[1:],
        title='', loc="center left", bbox_to_anchor=(1.05, 0.5),
        frameon=False,
    );
    plt.gca().set_ylim(-1, 35);
    figname = f"figure-continuous1d-split-{prob_setting}-rmsestest-{num_random}.pdf"
    fig.savefig(figname, bbox_inches="tight")
